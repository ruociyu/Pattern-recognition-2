# %% [markdown]
# ## Generating images with variational autoencoders

# %% [markdown]
# ### Sampling from latent spaces of images

# %% [markdown]
# ### Concept vectors for image editing

# %% [markdown]
# ### Variational autoencoders

# %% [markdown]
# ### Implementing a VAE with Keras

# %% [markdown]
# **VAE encoder network**

# %%
from tensorflow import keras
from tensorflow.keras import layers

latent_dim = 2

encoder_inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(32, 3, activation="relu", strides=2, padding="same")(encoder_inputs)
x = layers.Conv2D(64, 3, activation="relu", strides=2, padding="same")(x)
x = layers.Flatten()(x)
x = layers.Dense(16, activation="relu")(x)
z_mean = layers.Dense(latent_dim, name="z_mean")(x)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var], name="encoder")

# %%
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 28, 28, 1)]  0           []
#
#  conv2d (Conv2D)                (None, 14, 14, 32)   320         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 7, 7, 64)     18496       ['conv2d[0][0]']
#
#  flatten (Flatten)              (None, 3136)         0           ['conv2d_1[0][0]']
#
#  dense (Dense)                  (None, 16)           50192       ['flatten[0][0]']
#
#  z_mean (Dense)                 (None, 2)            34          ['dense[0][0]']
#
#  z_log_var (Dense)              (None, 2)            34          ['dense[0][0]']
#
# ==================================================================================================
# Total params: 69,076
# Trainable params: 69,076
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# **Latent-space-sampling layer**

# %%
import tensorflow as tf

class Sampler(layers.Layer):
    def call(self, z_mean, z_log_var):
        batch_size = tf.shape(z_mean)[0]
        z_size = tf.shape(z_mean)[1]
        epsilon = tf.random.normal(shape=(batch_size, z_size))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %% [markdown]
# **VAE decoder network, mapping latent space points to images**

# %%
latent_inputs = keras.Input(shape=(latent_dim,))
x = layers.Dense(7 * 7 * 64, activation="relu")(latent_inputs)
x = layers.Reshape((7, 7, 64))(x)
x = layers.Conv2DTranspose(64, 3, activation="relu", strides=2, padding="same")(x)
x = layers.Conv2DTranspose(32, 3, activation="relu", strides=2, padding="same")(x)
decoder_outputs = layers.Conv2D(1, 3, activation="sigmoid", padding="same")(x)
decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")

# %%
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 2)]               0
#
#  dense_1 (Dense)             (None, 3136)              9408
#
#  reshape (Reshape)           (None, 7, 7, 64)          0
#
#  conv2d_transpose (Conv2DTra  (None, 14, 14, 64)       36928
#  nspose)
#
#  conv2d_transpose_1 (Conv2DT  (None, 28, 28, 32)       18464
#  ranspose)
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 1)         289
#
# =================================================================
# Total params: 65,089
# Trainable params: 65,089
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **VAE model with custom `train_step()`**

# %%
class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.sampler = Sampler()
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss")
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [self.total_loss_tracker,
                self.reconstruction_loss_tracker,
                self.kl_loss_tracker]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var = self.encoder(data)
            z = self.sampler(z_mean, z_log_var)
            reconstruction = decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    keras.losses.binary_crossentropy(data, reconstruction),
                    axis=(1, 2)
                )
            )
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            total_loss = reconstruction_loss + tf.reduce_mean(kl_loss)
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "total_loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

# %% [markdown]
# **Training the VAE**

# %%
import numpy as np

(x_train, _), (x_test, _) = keras.datasets.mnist.load_data()
mnist_digits = np.concatenate([x_train, x_test], axis=0)
mnist_digits = np.expand_dims(mnist_digits, -1).astype("float32") / 255

vae = VAE(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam(), run_eagerly=True)
vae.fit(mnist_digits, epochs=30, batch_size=128)
# Out:
# Epoch 1/30
# 547/547 [==============================] - 118s 213ms/step - total_loss: 210.4766 - reconstruction_loss: 208.0905 - kl_loss: 2.3863
# Epoch 2/30
# 547/547 [==============================] - 120s 218ms/step - total_loss: 179.7517 - reconstruction_loss: 176.7406 - kl_loss: 3.0107
# Epoch 3/30
# 547/547 [==============================] - 120s 219ms/step - total_loss: 164.7206 - reconstruction_loss: 160.8294 - kl_loss: 3.8912
# Epoch 4/30
# 547/547 [==============================] - 118s 216ms/step - total_loss: 159.9349 - reconstruction_loss: 155.9916 - kl_loss: 3.9431
# Epoch 5/30
# 547/547 [==============================] - 120s 220ms/step - total_loss: 157.1776 - reconstruction_loss: 153.2010 - kl_loss: 3.9764
# Epoch 6/30
# 547/547 [==============================] - 119s 217ms/step - total_loss: 155.1288 - reconstruction_loss: 151.1480 - kl_loss: 3.9810
# Epoch 7/30
# 547/547 [==============================] - 119s 218ms/step - total_loss: 153.6833 - reconstruction_loss: 149.7515 - kl_loss: 3.9318
# Epoch 8/30
# 547/547 [==============================] - 120s 219ms/step - total_loss: 152.5289 - reconstruction_loss: 148.6569 - kl_loss: 3.8719
# Epoch 9/30
# 547/547 [==============================] - 121s 221ms/step - total_loss: 151.5981 - reconstruction_loss: 147.7536 - kl_loss: 3.8444
# Epoch 10/30
# 547/547 [==============================] - 121s 220ms/step - total_loss: 150.9622 - reconstruction_loss: 147.1253 - kl_loss: 3.8369
# Epoch 11/30
# 547/547 [==============================] - 119s 218ms/step - total_loss: 150.2661 - reconstruction_loss: 146.4360 - kl_loss: 3.8301
# Epoch 12/30
# 547/547 [==============================] - 119s 218ms/step - total_loss: 149.8080 - reconstruction_loss: 145.9837 - kl_loss: 3.8244
# Epoch 13/30
# 547/547 [==============================] - 117s 214ms/step - total_loss: 149.4480 - reconstruction_loss: 145.6231 - kl_loss: 3.8248
# Epoch 14/30
# 547/547 [==============================] - 113s 206ms/step - total_loss: 148.9917 - reconstruction_loss: 145.1701 - kl_loss: 3.8217
# Epoch 15/30
# 547/547 [==============================] - 113s 207ms/step - total_loss: 148.6644 - reconstruction_loss: 144.8445 - kl_loss: 3.8199
# Epoch 16/30
# 547/547 [==============================] - 121s 221ms/step - total_loss: 148.3455 - reconstruction_loss: 144.5211 - kl_loss: 3.8244
# Epoch 17/30
# 547/547 [==============================] - 121s 220ms/step - total_loss: 148.0443 - reconstruction_loss: 144.2285 - kl_loss: 3.8157
# Epoch 18/30
# 547/547 [==============================] - 120s 219ms/step - total_loss: 147.8510 - reconstruction_loss: 144.0212 - kl_loss: 3.8299
# Epoch 19/30
# 547/547 [==============================] - 120s 220ms/step - total_loss: 147.5336 - reconstruction_loss: 143.7052 - kl_loss: 3.8284
# Epoch 20/30
# 547/547 [==============================] - 120s 219ms/step - total_loss: 147.3111 - reconstruction_loss: 143.4952 - kl_loss: 3.8158
# Epoch 21/30
# 547/547 [==============================] - 120s 219ms/step - total_loss: 147.0626 - reconstruction_loss: 143.2500 - kl_loss: 3.8128
# Epoch 22/30
# 547/547 [==============================] - 118s 216ms/step - total_loss: 146.9596 - reconstruction_loss: 143.1386 - kl_loss: 3.8211
# Epoch 23/30
# 547/547 [==============================] - 119s 217ms/step - total_loss: 146.7224 - reconstruction_loss: 142.9046 - kl_loss: 3.8177
# Epoch 24/30
# 547/547 [==============================] - 119s 218ms/step - total_loss: 146.5031 - reconstruction_loss: 142.6889 - kl_loss: 3.8144
# Epoch 25/30
# 547/547 [==============================] - 119s 218ms/step - total_loss: 146.3631 - reconstruction_loss: 142.5479 - kl_loss: 3.8152
# Epoch 26/30
# 547/547 [==============================] - 120s 219ms/step - total_loss: 146.1760 - reconstruction_loss: 142.3608 - kl_loss: 3.8152
# Epoch 27/30
# 547/547 [==============================] - 120s 220ms/step - total_loss: 146.0555 - reconstruction_loss: 142.2489 - kl_loss: 3.8066
# Epoch 28/30
# 547/547 [==============================] - 122s 222ms/step - total_loss: 145.8703 - reconstruction_loss: 142.0443 - kl_loss: 3.8261
# Epoch 29/30
# 547/547 [==============================] - 119s 217ms/step - total_loss: 145.7185 - reconstruction_loss: 141.8953 - kl_loss: 3.8231
# Epoch 30/30
# 547/547 [==============================] - 120s 219ms/step - total_loss: 145.6279 - reconstruction_loss: 141.8068 - kl_loss: 3.8210

# %% [markdown]
# **Sampling a grid of images from the 2D latent space**

# %%
import matplotlib.pyplot as plt

n = 30
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))

grid_x = np.linspace(-1, 1, n)
grid_y = np.linspace(-1, 1, n)[::-1]

for i, yi in enumerate(grid_y):
    for j, xi in enumerate(grid_x):
        z_sample = np.array([[xi, yi]])
        x_decoded = vae.decoder.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[
            i * digit_size : (i + 1) * digit_size,
            j * digit_size : (j + 1) * digit_size,
        ] = digit

plt.figure(figsize=(15, 15))
start_range = digit_size // 2
end_range = n * digit_size + start_range
pixel_range = np.arange(start_range, end_range, digit_size)
sample_range_x = np.round(grid_x, 1)
sample_range_y = np.round(grid_y, 1)
plt.xticks(pixel_range, sample_range_x)
plt.yticks(pixel_range, sample_range_y)
plt.xlabel("z[0]")
plt.ylabel("z[1]")
plt.axis("off")
plt.imshow(figure, cmap="Greys_r")

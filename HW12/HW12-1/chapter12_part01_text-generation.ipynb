# %% [markdown]
# # Generative deep learning

# %% [markdown]
# ## Text generation

# %% [markdown]
# ### A brief history of generative deep learning for sequence generation

# %% [markdown]
# ### How do you generate sequence data?

# %% [markdown]
# ### The importance of the sampling strategy

# %% [markdown]
# **Reweighting a probability distribution to a different temperature**

# %%
import numpy as np
def reweight_distribution(original_distribution, temperature=0.5):
    distribution = np.log(original_distribution) / temperature
    distribution = np.exp(distribution)
    return distribution / np.sum(distribution)

# %% [markdown]
# ### Implementing text generation with Keras

# %% [markdown]
# #### Preparing the data

# %% [markdown]
# **Downloading and uncompressing the IMDB movie reviews dataset**

# %%
# !wget https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# !tar -xf aclImdb_v1.tar.gz
# Out:
# --2022-12-09 07:09:24--  https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# Resolving ai.stanford.edu (ai.stanford.edu)... 171.64.68.10
# Connecting to ai.stanford.edu (ai.stanford.edu)|171.64.68.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84125825 (80M) [application/x-gzip]
# Saving to: ‘aclImdb_v1.tar.gz’
#
# aclImdb_v1.tar.gz   100%[===================>]  80.23M  17.5MB/s    in 7.9s
#
# 2022-12-09 07:09:33 (10.1 MB/s) - ‘aclImdb_v1.tar.gz’ saved [84125825/84125825]

# %% [markdown]
# **Creating a dataset from text files (one file = one sample)**

# %%
import tensorflow as tf
from tensorflow import keras
dataset = keras.utils.text_dataset_from_directory(
    directory="aclImdb", label_mode=None, batch_size=256)
dataset = dataset.map(lambda x: tf.strings.regex_replace(x, "<br />", " "))
# Out:
# Found 100006 files belonging to 1 classes.

# %% [markdown]
# **Preparing a `TextVectorization` layer**

# %%
from tensorflow.keras.layers import TextVectorization

sequence_length = 100
vocab_size = 15000
text_vectorization = TextVectorization(
    max_tokens=vocab_size,
    output_mode="int",
    output_sequence_length=sequence_length,
)
text_vectorization.adapt(dataset)

# %% [markdown]
# **Setting up a language modeling dataset**

# %%
def prepare_lm_dataset(text_batch):
    vectorized_sequences = text_vectorization(text_batch)
    x = vectorized_sequences[:, :-1]
    y = vectorized_sequences[:, 1:]
    return x, y

lm_dataset = dataset.map(prepare_lm_dataset, num_parallel_calls=4)

# %% [markdown]
# #### A Transformer-based sequence-to-sequence model

# %%
import tensorflow as tf
from tensorflow.keras import layers

class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, input_dim, output_dim, **kwargs):
        super().__init__(**kwargs)
        self.token_embeddings = layers.Embedding(
            input_dim=input_dim, output_dim=output_dim)
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=output_dim)
        self.sequence_length = sequence_length
        self.input_dim = input_dim
        self.output_dim = output_dim

    def call(self, inputs):
        length = tf.shape(inputs)[-1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_tokens = self.token_embeddings(inputs)
        embedded_positions = self.position_embeddings(positions)
        return embedded_tokens + embedded_positions

    def compute_mask(self, inputs, mask=None):
        return tf.math.not_equal(inputs, 0)

    def get_config(self):
        config = super(PositionalEmbedding, self).get_config()
        config.update({
            "output_dim": self.output_dim,
            "sequence_length": self.sequence_length,
            "input_dim": self.input_dim,
        })
        return config


class TransformerDecoder(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(
          num_heads=num_heads, key_dim=embed_dim)
        self.attention_2 = layers.MultiHeadAttention(
          num_heads=num_heads, key_dim=embed_dim)
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation="relu"),
             layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.layernorm_3 = layers.LayerNormalization()
        self.supports_masking = True

    def get_config(self):
        config = super(TransformerDecoder, self).get_config()
        config.update({
            "embed_dim": self.embed_dim,
            "num_heads": self.num_heads,
            "dense_dim": self.dense_dim,
        })
        return config

    def get_causal_attention_mask(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size, sequence_length = input_shape[0], input_shape[1]
        i = tf.range(sequence_length)[:, tf.newaxis]
        j = tf.range(sequence_length)
        mask = tf.cast(i >= j, dtype="int32")
        mask = tf.reshape(mask, (1, input_shape[1], input_shape[1]))
        mult = tf.concat(
            [tf.expand_dims(batch_size, -1),
             tf.constant([1, 1], dtype=tf.int32)], axis=0)
        return tf.tile(mask, mult)

    def call(self, inputs, encoder_outputs, mask=None):
        causal_mask = self.get_causal_attention_mask(inputs)
        if mask is not None:
            padding_mask = tf.cast(
                mask[:, tf.newaxis, :], dtype="int32")
            padding_mask = tf.minimum(padding_mask, causal_mask)
        attention_output_1 = self.attention_1(
            query=inputs,
            value=inputs,
            key=inputs,
            attention_mask=causal_mask)
        attention_output_1 = self.layernorm_1(inputs + attention_output_1)
        attention_output_2 = self.attention_2(
            query=attention_output_1,
            value=encoder_outputs,
            key=encoder_outputs,
            attention_mask=padding_mask,
        )
        attention_output_2 = self.layernorm_2(
            attention_output_1 + attention_output_2)
        proj_output = self.dense_proj(attention_output_2)
        return self.layernorm_3(attention_output_2 + proj_output)

# %% [markdown]
# **A simple Transformer-based language model**

# %%
from tensorflow.keras import layers
embed_dim = 256
latent_dim = 2048
num_heads = 2

inputs = keras.Input(shape=(None,), dtype="int64")
x = PositionalEmbedding(sequence_length, vocab_size, embed_dim)(inputs)
x = TransformerDecoder(embed_dim, latent_dim, num_heads)(x, x)
outputs = layers.Dense(vocab_size, activation="softmax")(x)
model = keras.Model(inputs, outputs)
model.compile(loss="sparse_categorical_crossentropy", optimizer="rmsprop")

# %% [markdown]
# ### A text-generation callback with variable-temperature sampling

# %% [markdown]
# **The text-generation callback**

# %%
import numpy as np

tokens_index = dict(enumerate(text_vectorization.get_vocabulary()))

def sample_next(predictions, temperature=1.0):
    predictions = np.asarray(predictions).astype("float64")
    predictions = np.log(predictions) / temperature
    exp_preds = np.exp(predictions)
    predictions = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, predictions, 1)
    return np.argmax(probas)

class TextGenerator(keras.callbacks.Callback):
    def __init__(self,
                 prompt,
                 generate_length,
                 model_input_length,
                 temperatures=(1.,),
                 print_freq=1):
        self.prompt = prompt
        self.generate_length = generate_length
        self.model_input_length = model_input_length
        self.temperatures = temperatures
        self.print_freq = print_freq

    def on_epoch_end(self, epoch, logs=None):
        if (epoch + 1) % self.print_freq != 0:
            return
        for temperature in self.temperatures:
            print("== Generating with temperature", temperature)
            sentence = self.prompt
            for i in range(self.generate_length):
                tokenized_sentence = text_vectorization([sentence])
                predictions = self.model(tokenized_sentence)
                next_token = sample_next(predictions[0, i, :])
                sampled_token = tokens_index[next_token]
                sentence += " " + sampled_token
            print(sentence)

prompt = "This movie"
text_gen_callback = TextGenerator(
    prompt,
    generate_length=50,
    model_input_length=sequence_length,
    temperatures=(0.2, 0.5, 0.7, 1., 1.5))

# %% [markdown]
# **Fitting the language model**

# %%
model.fit(lm_dataset, epochs=50, callbacks=[text_gen_callback])
# Out:
# Epoch 1/50
# 391/391 [==============================] - ETA: 0s - loss: 5.3559== Generating with temperature 0.2
# This movie film has was plenty absolutely to brilliant that movies spouts in everyday all movies this were is great a job strong ive in seen paris only iii with and this [UNK] entertaining in as 1950 their films aspects now put has any an case allstar and cast both of dump
# == Generating with temperature 0.5
# This movie movie was couldnt a act complete well waste acted time with i 2 have out come of going movie to greatly watch never it jump properly from the correctly same channel name including that the ariel screen is career filled list with of that 95 seems minutes at some the
# == Generating with temperature 0.7
# This movie is is dismissed decent it film better as filmed a the god hospital should try try to did write not his spend punishment many until violence i its been postwar completely god deep better attention than form great my deal fully with recommend a a little letdown spoilers for acting
# == Generating with temperature 1.0
# This movie movie makes is an plain idea terrible of concept movie that here cost is someone bound had to called let through me a laugh det philosophical [UNK] ways shirts the life fact of it the uses movie five and power after to each read credits mainly want naked to skating
# == Generating with temperature 1.5
# This movie movie was viewing supposed a to high believe rating that crap hated all all i the watched saddest made time me slot an when online it series both park are was extremely great funny comic fake actress talky who like with driving that the after most millions nothing of by
# 391/391 [==============================] - 184s 455ms/step - loss: 5.3559
# Epoch 2/50
# 391/391 [==============================] - ETA: 0s - loss: 4.8151== Generating with temperature 0.2
# This movie movie is has about a what comedic it typical is bad all yet suspense all no you very may silly envy to just be what available is on bloody movies moving a and [UNK] then button ride on in the a [UNK] small snl town they there are are always
# == Generating with temperature 0.5
# This movie must is be out one to of see those at films the that time talks around the [UNK] 1960s of during elephant three man universal is company told [UNK] by that the he ernest can [UNK] take the his head own caught himself and in then medical couldnt bed change
# == Generating with temperature 0.7
# This movie film should is have storyline had actors any with little the about dark and plot rightfully elements so but the it movie comes looks from real the life cast and whoopi is goldberg danced as willy rich as and portrayed alex as [UNK] a fighting creepy feature man does loses
# == Generating with temperature 1.0
# This movie is is beyond truly your one your sentence fine  science fiction to play a film will also be mentioned and certainly its one of those shows you know you see there is no story to be quite unfamiliar with stephen [UNK] no dialogue whatsoever its cool bad as the
# == Generating with temperature 1.5
# This movie is is really the the worst greatest movie actors ever ever role made ever in existed this today one the is human about shame 15 i people felt have the to fact see its it been never my [UNK] life remember again when i you may can not look spoil
# 391/391 [==============================] - 179s 456ms/step - loss: 4.8151
# Epoch 3/50
# 391/391 [==============================] - ETA: 0s - loss: 4.6045== Generating with temperature 0.2
# This movie is acted a and beautifully excellent leaves work you for missed their it parts years from everyone the ive best seen since including 2 this on year all in of my the life filming but it still was been very a made lost posting in a mind lot but of
# == Generating with temperature 0.5
# This movie movie is is [UNK] its [UNK] time because funny it every exists time where im you trying thinking to there find it something normal from suddenly putting a the two audience million moves dollars in ok this at movie the where prize a is group based of around women a
# == Generating with temperature 0.7
# This movie movie had came a to lot be of granted absolute its troma hailed got as like which the now word this [UNK] is 1998 just for what the a producers brilliant project crew to who save would their probably money be back beautiful in and their life newly although ripped
# == Generating with temperature 1.0
# This movie movie is is lousy good the for credits a i bank could but say im that a [UNK] fan for of my mary life a 15 little years dude what see a this shame above if offspring their were dvds very executives good around to the enjoy animation i i
# == Generating with temperature 1.5
# This movie movie opened has back problems been because unheard of of life film when director the local film public one wanted its to [UNK] sit host through bill as [UNK] scarlett an forgiving actor as as portrayed the the hiding rather behind than [UNK] alcoholic for charles any macdowell show [UNK]
# 391/391 [==============================] - 179s 456ms/step - loss: 4.6045
# Epoch 4/50
# 391/391 [==============================] - ETA: 0s - loss: 4.4816== Generating with temperature 0.2
# This movie is was very awful dull i film have the no violence choice the ever cinematography as is awful worse have  the part of this attempt at without the stereotypical character i dont know what happened to that division and the stupid channels theres a plot long i never got
# == Generating with temperature 0.5
# This movie is is a quite disaster good horror and samantha is astor pretty simply attractive as as a in [UNK] this yarn piece of as slick the [UNK] last and taxi beautiful driver i the saw second the the film acting said is its superb just the a performances very by
# == Generating with temperature 0.7
# This movie film was made the by only marketing clint will eastwood smith be as chosen a as completely the trusting beautiful from [UNK] warner is bros a films star [UNK] led animated by films david like [UNK] the [UNK] modern and classic davis [UNK] and [UNK] leads the a fans routine
# == Generating with temperature 1.0
# This movie isnt truly exactly the how case we in all a know life why going it out actually to is be this some movie movie that because the it french had actors some with great a cast visually [UNK] of but mindless the nothing lead interesting actors [UNK] that who lacks
# == Generating with temperature 1.5
# This movie piece is of only crap cinema i im have usually yet a to bit offer with the my exception opinion being is a as huge bad let as up myself to why what i i consider think this of movie the mostly american in movies my i time do i
# 391/391 [==============================] - 179s 456ms/step - loss: 4.4816
# Epoch 5/50
# 391/391 [==============================] - ETA: 0s - loss: 4.3942== Generating with temperature 0.2
# This movie movie must is have not just been simply so on awful a  [UNK] who worked to feature the acting skills to entertain and keep your attention is [UNK] cowritten by the lack of [UNK] many emotional originality and provocative men and [UNK] in the sun [UNK] the film is
# == Generating with temperature 0.5
# This movie movie is had like rather [UNK] typical legs western for main made character up to missing be and anything by new the reality popular shows hype 1 surrounding to the be stupid 12 and years 9 old year i old guess and kids [UNK] to is see the this same
# == Generating with temperature 0.7
# This movie film for about the a [UNK] quarter evelyn of [UNK] both and actors aunt who [UNK] in [UNK] hollywood who that thought they is would and not the get writers the for best example directors the at films such [UNK] as [UNK] the [UNK] henry of winkler the really conflicted
# == Generating with temperature 1.0
# This movie 2003 was was truly a the [UNK] first of experience the this her was film her made best and the all [UNK] of trademarks it pressure was and a [UNK] great but metaphor then was she the retired first but that a was writer the and triumph [UNK] of in
# == Generating with temperature 1.5
# This movie is has really an impact attack love over [UNK] the [UNK] first years penny is [UNK] a [UNK] must of have [UNK] not [UNK] only fine add in every the second story each ever character knows walk that that [UNK] what is a turning beautiful point piece to of [UNK]
# 391/391 [==============================] - 180s 458ms/step - loss: 4.3942
# Epoch 6/50
# 391/391 [==============================] - ETA: 0s - loss: 4.3260== Generating with temperature 0.2
# This movie sequel is starts nowhere out like not a action ok movie id if watch it an sounded action interesting lot but of the the way plot it the made story it seems literally same [UNK] 20 every years character the takes dialogue care holding of you a into character the
# == Generating with temperature 0.5
# This movie version is by complete far timothy one [UNK] of away many must hits now you men it and is all a the lot way different way than that that [UNK] allows was twin to of break [UNK] your spell [UNK] which without is any motivated real by monster the all
# == Generating with temperature 0.7
# This movie lowbudget seems was to more be trash had than no attack reason on never broadcast thought this of film a the domestic acting [UNK] poorly as [UNK] the is costumes so are refreshing the ensuing special scenes effects are are poor decent the but settings hopefully are the really story
# == Generating with temperature 1.0
# This movie might was be because in i the was cover a up 1956 opening date with with teen the stars [UNK] of a the ubiquitous land moment of right the after acting for is a seriously [UNK] deadly full intro of then [UNK] he blood [UNK] horror into lieutenant something [UNK]
# == Generating with temperature 1.5
# This movie movie blew always your funny slightest little hint gag of kiddie stupid sex jokes romp and followed stupid them speech with this [UNK] one [UNK] [UNK] on conceived the television [UNK] screen it as didnt good win she over deserved 20 decent third  it but sadly the dumb viewer
# 391/391 [==============================] - 179s 457ms/step - loss: 4.3260
# Epoch 7/50
# 391/391 [==============================] - ETA: 0s - loss: 4.2706== Generating with temperature 0.2
# This movie is undoubtedly underrated one and of most the [UNK] most finest courageous movies of ever the played simple on story life but yakuza what a more [UNK] to than their a prostitute father the after direction the is film poor a pretentious [UNK] film done with until a the night
# == Generating with temperature 0.5
# This movie spanish is that violent gonna may be have touching used my and parents [UNK] with is additional proof material why this i is confess the to whole an movie art without film trying the to [UNK] go [UNK] ahead dont i only know ever how thought they the were plot
# == Generating with temperature 0.7
# This movie movie is is almost an wonderful absurd one not every great plot ensemble lines cast in you a can sure act there and are the so kids many will characters love in who each is other shaking they their find lives on and a majority little of boy the and
# == Generating with temperature 1.0
# This movie epic is [UNK] not by [UNK] me or he [UNK] is you what see you him cant 10 get lines the to critic you but and because you then are you from get a to [UNK] the version movie of the les same the sort prisoner of wants evil to
# == Generating with temperature 1.5
# This movie series has is affects not teens being in stolen everyone from loves the this story movie is has funny the lines writing of the the artists movie care is it so is funny in funny the movies zany and [UNK] the civil jokes [UNK] are to hilarious scratch somehow form
# 391/391 [==============================] - 180s 459ms/step - loss: 4.2706
# Epoch 8/50
# 391/391 [==============================] - ETA: 0s - loss: 4.2252== Generating with temperature 0.2
# This movie could had ever been have like been up a to sleeper like chore a so movie see such how pretty bad painful it you is could because make of it a without comedy fail stupid miserably all the write cast minutes isnt should even be be marketed expected it attempted
# == Generating with temperature 0.5
# This movie was was very a entertaining small piece piece for of adults socalled there special was effects a no ninja depth camerawork whatsoever and is far gorgeous from it the the editing undemanding and and virgin melville cutting charles edge dance polite was loud the voice added of such keatons a
# == Generating with temperature 0.7
# This movie is was one pretty of bad my movies local and guy i who watched have the [UNK] weekend discussing the nasty movie ninjas and [UNK] the killing worst himself calling in him it is looks totally like unreal he scene had here the now ninja deed spoiler as galore for
# == Generating with temperature 1.0
# This movie is was an one effort lousy i script havent i given seen away the with movie the unfortunately whole it thing had is no entirely reason substance to that watch i than felt the the film acting was was fine beyond as all to its watch expectation  the subject
# == Generating with temperature 1.5
# This movie series is starring years paul ago lukas and called man out but of for one a reason wellknown to amid carry the it multiple as these those avid elements [UNK] so park with that random the controversial story celebrity concerns college an student old named buses voice only directed to
# 391/391 [==============================] - 180s 458ms/step - loss: 4.2252
# Epoch 9/50
# 391/391 [==============================] - ETA: 0s - loss: 4.1866== Generating with temperature 0.2
# This movie is was great not and only inspirational by i its need struggle to with see children it however with if the you latter studied half the deals ghetto with issues a about past modern act bad the people simmons fighting comes as through a out way the of film the
# == Generating with temperature 0.5
# This movie could is do very with nothing a whatsoever plot in overall the its average very to poorly write written even dialogue while failed the to basically [UNK] make a you complete cant even believe understand that the this [UNK] is of forced a to newspaper play the the cast part
# == Generating with temperature 0.7
# This movie has is a wonderfully surprisingly made moving film movie its its got all the literally tony [UNK] lo plays looking a [UNK] little cop silent who [UNK] wants one forth brother with played his by role michael the douglas story [UNK] kid as who a tells younger his one kid
# == Generating with temperature 1.0
# This movie was needs great better restoration acting and and dialogue better which story i line hardly ate see it the being first a movie hit that the i film liked [UNK] it of was all a this sudden [UNK] and on regime a in personal one struggle of to the not
# == Generating with temperature 1.5
# This movie is has a to lot say for about the the battle scenery of the ohio west [UNK] when [UNK] it novelist turns pollack and a writers [UNK] full in intentions his the character feeling consistent and and wholly utterly [UNK] [UNK] miniseries [UNK] the out story after two going minutes
# 391/391 [==============================] - 181s 462ms/step - loss: 4.1866
# Epoch 10/50
# 391/391 [==============================] - ETA: 0s - loss: 4.1528== Generating with temperature 0.2
# This movie movie is really bad painful due to to the the practical fact jokes that in gets the krueger truth it the just family doesnt is just terrible normal its gay funny and and it thats shows portuguese how magic common carried sense the also book sends to the no comedy
# == Generating with temperature 0.5
# This movie is is extremely simply uneven citizen and x whatever bashing boot of call similar with evil fritz and persona 1974 added quentin the tarantinos ealing random comedies charming section reversal of at kerry [UNK] [UNK] daring [UNK] comedy to author establish sir themselves walter under [UNK] the direction effort from
# == Generating with temperature 0.7
# This movie film was deals shot with out a lows similar racial story issues told tried by to some make ultimately people proceedings compare like this the is occult not incest that nor common can movie be be funny the i acting can some most of of the the dialog actors also
# == Generating with temperature 1.0
# This movie is was an excellent excellent amateur place depiction the of plot the but twins of sucked the lack last of blood talent was i just mean a the pretty [UNK] boy things played happen out if in the huge movie city  that wasnt always but this movie had neither
# == Generating with temperature 1.5
# This movie is is a [UNK] joy well since you the missed mafia opportunity i given remember a seeing deaf it scorpion intense [UNK] and adolescent incredible male performances fantasy by well respective rock imagery aka fantastic the powerful incredible stranger scifi in top a of good my beautiful opinion [UNK] budding
# 391/391 [==============================] - 179s 457ms/step - loss: 4.1528
# Epoch 11/50
# 391/391 [==============================] - ETA: 0s - loss: 4.1240== Generating with temperature 0.2
# This movie movie is is so really bad funny its it [UNK] just people happens simply to dont be need fooled is by a some voice new sounds steals like the he everytime causes he the opens devil a with talking the his next shotgun big tarantino sloppy finally acting he a
# == Generating with temperature 0.5
# This movie [UNK] is it shocking a and comedy powerful about in [UNK] the of heather decided graham it in is two way different funnier then fools the both ending [UNK] mimi and and john margaret [UNK] [UNK] is and [UNK] i [UNK] highly it recommend literally it to to anyone all
# == Generating with temperature 0.7
# This movie is was a very really overrated good movie storyline the and acting the i main think title it is was so not bad funny it not could the have makers used to child decide of which a in great [UNK] movie [UNK] festival [UNK] for problem it lessons doesnt they
# == Generating with temperature 1.0
# This movie movie is is [UNK] [UNK] done and a same nice movie soundtrack the instead actors of many their drama [UNK] side i story think for this most movie certainly [UNK] could a have better been life done of in using slowmotion a to [UNK] experience not the to overall mention
# == Generating with temperature 1.5
# This movie was simply awful brilliant i in was need respect of the the trivia character [UNK] [UNK] not gives she a power flying she away was earlier even the more last plain 10 movement minutes theres into a the lot talking of about people this walking movie up as in trash
# 391/391 [==============================] - 179s 457ms/step - loss: 4.1240
# Epoch 12/50
# 391/391 [==============================] - ETA: 0s - loss: 4.0984== Generating with temperature 0.2
# This movie super has [UNK] to [UNK] offer brain in machine hell film hole is id a say fan preferably would after be the in same my league opinion at too least long not too so easily well benefits done from effects versatility just there so is i no take more that
# == Generating with temperature 0.5
# This movie movie is is very one predictable of maybe my the biggest largest problem copy in is the the ending guy of who the plays hell his not opinion really [UNK] the was movie of he the didnt hockey know mask he like is objects god and turns expressing into his
# == Generating with temperature 0.7
# This movie is is like quite raiders a of robert the altmans lost [UNK] ark script a is story long star with unfortunately close there minded is robots no down one the behaves no like criminals badly a acted natural often environment but and the hes whole so group strange is and
# == Generating with temperature 1.0
# This movie movie was is excellent at and the the same end time it that scared impressed the me acting so is much all more about subtle the and surprise deep ending romantic makes hawn the novel same of name the i direction had gets grow right confused into very her sad
# == Generating with temperature 1.5
# This movie film made has in a many specific ways location can [UNK] be the considered big stunning [UNK] but by it the be effects to were reach very in screenwriters its and age [UNK] the felt story hard was was put previously up killed right another maybe different not name here
# 391/391 [==============================] - 180s 460ms/step - loss: 4.0984
# Epoch 13/50
# 391/391 [==============================] - ETA: 0s - loss: 4.0754== Generating with temperature 0.2
# This movie isnt is a one bad for review you the by only the time mass you of can a think minimum about from this all movie people tries who to planned see a every lot pilot of in the one tv of director them george dont [UNK] [UNK] and i also
# == Generating with temperature 0.5
# This movie has is to two be different one as of the the finest human movies actresses it in is the very story strong of acting simple and story very i good think cinematography this and is not smart the people other who in who it have is won pretty a youngsters
# == Generating with temperature 0.7
# This movie is was flopped addictive much i the can boy relate use to the live term action loosely any based more on on the the characters screen may play engaging off but the its character quite is unlikeable played filled by with intensity so as tuned it in may rather never
# == Generating with temperature 1.0
# This movie is is stylish one but of more the action most is influential [UNK] action and packed inane film the ive characters watched of with the the same third name of since the i first have saw found this this show film from in the the lead true but story it
# == Generating with temperature 1.5
# This movie is is super incredible a as real shown h i g have and studied it [UNK] so cinema im [UNK] not glad sure that if this its was in a that couple [UNK] full has of [UNK] his and ability [UNK] to through live the in underneath the walter [UNK]
# 391/391 [==============================] - 179s 456ms/step - loss: 4.0754
# Epoch 14/50
# 391/391 [==============================] - ETA: 0s - loss: 4.0546== Generating with temperature 0.2
# This movie is is slow boring around and so unrealistic annoying if that youre would watching want a to manos salvage the the ghoulies whole series plot they is search to for have some happened kind going of to on have it some wasnt stock terribly footage original thats footage half of
# == Generating with temperature 0.5
# This movie is may a seem great completely 1st blind the after exception drinking the the movie brilliant portrays terrifying a adolescent frustration strip throughout hell the insane only world watching its twenty silly pigs not being content sexy the and outline the of producers the via movie lois succeeded lane in
# == Generating with temperature 0.7
# This movie film is offers incredibly an overlong incredibly and boring [UNK] film production although in [UNK] the source subject material matter may some be very [UNK] campy with for a those break who [UNK] dont might talk have about any infidelity [UNK] to do their research characters and actually they completely
# == Generating with temperature 1.0
# This movie is is so the funny campaign line that is i it dont with even that money on system this that movie it became hits a the funny textbook trey example parker of fell the a hard joke genius there behind is blazing also saddles comedy fake style and report south
# == Generating with temperature 1.5
# This movie bitch is from fantastic the staring king uk of obviously darkness today this were movie not producer enjoyable or looking if for they america had then been read 100 as of about the the release whole of thing monkey i island didnt myself find actually out watching god a for
# 391/391 [==============================] - 179s 458ms/step - loss: 4.0546
# Epoch 15/50
# 391/391 [==============================] - ETA: 0s - loss: 4.0359== Generating with temperature 0.2
# This movie wasnt was just a an parody inch of lovely the graphic new nature york of times us and i this found one it disaster did more it action was than fun inspired and however scary that movie i the most movies interesting ive only ever seen seen i with know
# == Generating with temperature 0.5
# This movie movie was johnson very didnt much [UNK] know ignorance the of plot the of main [UNK] person of [UNK] the about [UNK] to of [UNK] [UNK] other about than [UNK] [UNK] was know the other greek reviews [UNK] made other clear people by died the he war said i he
# == Generating with temperature 0.7
# This movie was features so one much level says it the was case good with to the suit [UNK] orange to borrows make something good new  in all aspects its as if it was the story of this especially one as the first one and only has a few strange drug
# == Generating with temperature 1.0
# This movie is is weird like no most other [UNK] little that psycho is [UNK] way is way a off twisted futuristic group movie thats set dead in [UNK] the this whole went film right does further it but is at still best it boring has badly a edited great crowd [UNK]
# == Generating with temperature 1.5
# This movie is has a its feeling plot of that a the few writers comments can about identify something with more them than this anything slow as moving [UNK] as are it the is whole people [UNK] who to was [UNK] slightly by amused the by movie the [UNK] effort [UNK] it
# 391/391 [==============================] - 179s 457ms/step - loss: 4.0359
# Epoch 16/50
# 391/391 [==============================] - ETA: 0s - loss: 4.0190== Generating with temperature 0.2
# This movie was is low just budget a once classic you that all you films get always caught kept the the attention line of or the lack action of without any preaching action in all basic it ways is first a class movie act that and kept when you it dont did
# == Generating with temperature 0.5
# This movie film is is about an a fbi police cop officer who filmed finds his himself son from himself [UNK] loving between it help becomes us a that bit is [UNK] well because drawn the out flashbacks beauty of played him out seem to the call way from that the time
# == Generating with temperature 0.7
# This movie movie was is a so scare poor where is to he my might [UNK] have the used hero but too it god was he only on a the parts unrealistic he situations was and so the the fat movie boy character is i a think teenage the boy movies is
# == Generating with temperature 1.0
# This movie movie was actually dull a it green starts screen out with as susan some [UNK] of on the the banana playing [UNK] stars some as of a it lifetime cant as even she the promises [UNK] of all 30s there and she [UNK] gives off a the stronger best performance
# == Generating with temperature 1.5
# This movie movie is was about very a poor great attempt movie at and demonstration it of is an trying alltime to making [UNK] action things the he last actually book was the hoping greatest to score be the objective scenes it and was [UNK] about once the you movie come tries
# 391/391 [==============================] - 179s 457ms/step - loss: 4.0190
# Epoch 17/50
# 391/391 [==============================] - ETA: 0s - loss: 4.0038== Generating with temperature 0.2
# This movie movie is is about pretty 3 graphic guys scenes dressed are [UNK] all for pose bullets if that there would is be the a highlight demon reel whose claiming body to go be on it a however [UNK] seeing looks a okay woman few holding things his together [UNK] she
# == Generating with temperature 0.5
# This movie movie is is made so about worthless that which a becomes whole more lot ridiculous of movies peoples you valuable really [UNK] dont this bother is your like running watching inspiring others movies soccer apart spans from the [UNK] 20s of and 3 history different no women matter in the
# == Generating with temperature 0.7
# This movie is is about amazing four i college have friends taped ordered it my outside friends three that friends paid keeps from off them all the the time time a they [UNK] are about developed their and lives the over idea inhabitants that of be several found years them ago leaving
# == Generating with temperature 1.0
# This movie has was absolutely said horrible that the it beginning feels john like cassavetes continuity playing if the conspiracy filmmakers is had presented [UNK] from plight a for [UNK] days maybe gangsters it are was dumb just but slavery at is least simply entertaining terrible with despite giggling dignity and who
# == Generating with temperature 1.5
# This movie is is simply like a the romantic very farce dull set predictable against medieval the barren asian [UNK] furniture an it american [UNK] virgin fooled well by beyond the the colorful public characters domain which 2 also peasants [UNK] seem an completely explosion [UNK] in with the modern experiences weapons
# 391/391 [==============================] - 179s 458ms/step - loss: 4.0038
# Epoch 18/50
# 391/391 [==============================] - ETA: 0s - loss: 3.9900== Generating with temperature 0.2
# This movie neglected reflects and on on your home way [UNK] to breakfast adequately of paying sandy there and which no is intention nice when what they else are could just do go without back making it fun happen of andy course meets the a great perfect cast voice all actress i
# == Generating with temperature 0.5
# This movie borderline is made totally in forget fact what it it was is just an quite embarrassing crisp moment and he completely is forgot the to person end from elizabeth supporting taylor her she script must is die welcome from and the youll cast be a as hoot she but tries
# == Generating with temperature 0.7
# This movie film is is up horrible there it with is many so [UNK] many about layers what of in it the this dialogue never is so able characterdriven to flashbacks give to you each ive seem wondered to if know it any more more and the its acting like is there
# == Generating with temperature 1.0
# This movie movie was is pretentious because yes it b is that actually true makes i the was movies a like mockery that of id low rather budget than the make movie out in of oh any no one nothing wants to to much annoy end even the if no you acting
# == Generating with temperature 1.5
# This movie was is very absolutely well beautiful thought very provoking well the done acting with was characters class i and was the convincing great and albums it i showed had it just really a nice few sense movies and over it [UNK] was the very story little is [UNK] intriguing and
# 391/391 [==============================] - 179s 456ms/step - loss: 3.9900
# Epoch 19/50
# 391/391 [==============================] - ETA: 0s - loss: 3.9772== Generating with temperature 0.2
# This movie is examination better hollywood than but it this is movie a a huge bit tax it and is have just failed pulled miserably from off one in painfully the unfunny last and meg unwatchable ryan jack stars lemmon as and walter matthau matthau is really two good loving [UNK] their
# == Generating with temperature 0.5
# This movie film is starts for slow a horror college movie class two then sisters serves could as be a the sequel sophomoric to [UNK] actual [UNK] prostitutes [UNK] on an a ancient drug tale that or seems any it student puzzles porno her class creepy created dog by and satan especially
# == Generating with temperature 0.7
# This movie was is a definitely short one excellently of shot those best wellknown french movies spirit of which the seem prospect forced of i setting am myself a to hard use to of sound the then music i cannot sincerely find obtain anything blue on and video dont and have run
# == Generating with temperature 1.0
# This movie is went plain by embarrassing accident it i should could have have spent stayed something up worse and which worse is after the having course admitted acclaimed paranoia by and this the time case what so a ever confusion me except is a the bit [UNK] the in insects regard
# == Generating with temperature 1.5
# This movie is gets not on because the its social much politics better its than not that that it i was can [UNK] partly about because the we glory do of not seeing too it as because a we war showed still in coming right to now face go death charlie the
# 391/391 [==============================] - 179s 456ms/step - loss: 3.9772
# Epoch 20/50
# 391/391 [==============================] - ETA: 0s - loss: 3.9652== Generating with temperature 0.2
# This movie version is of the [UNK] [UNK] story goes ive [UNK] been an just action for fantasy [UNK] and character [UNK] are and developed the to [UNK] make own this research one the has [UNK] to he [UNK] is on based the the two truth [UNK] men [UNK] the and strain
# == Generating with temperature 0.5
# This movie movie couldnt is do not that try its to not make entertain a enough movie tough so but all definitely they worth had it very please few the legal editing rules was if attractive for and this beautiful waste film of on the this cutting dog off it watching is
# == Generating with temperature 0.7
# This movie film is is definitely a a well very told well poorly into executed a kind thriller of it suspense trying probably to for make a him movie in about spite a of throwing a hiding blood and and all a of sudden that it is is required unusual watching under
# == Generating with temperature 1.0
# This movie is is mostly everything visually one dazzling could and argue probably the the worst best remake of directed the by [UNK] bitter ali moon g documentary now [UNK] done picks by up alfred and hitchcock on carried the this film one has way a to naive take and chances you
# == Generating with temperature 1.5
# This movie doesnt pulled seem off at any all cost the this [UNK] movie were have getting problems how with would the have scene been that done employees with of that the idea market of sadly its the something best you happened can is catch that your in late ones rodney the
# 391/391 [==============================] - 179s 457ms/step - loss: 3.9652
# Epoch 21/50
# 391/391 [==============================] - ETA: 0s - loss: 3.9544== Generating with temperature 0.2
# This movie game is version one of of the [UNK] [UNK] guns hollywood and hire indian the agents professional required actors in only this an game example consultant of for errors socalled this pacing game is don leaden [UNK] and plays [UNK] sincerity [UNK] to to the the point point that where
# == Generating with temperature 0.5
# This movie movie was will designed alter to your showcase logical to atlantic rot watch past the the molly [UNK] golf and pepper richard up benjamin as [UNK] a co jazz operative musician and parents the who following highlight their they adventures generally forget meet the is ins glossed and over town
# == Generating with temperature 0.7
# This movie could is have almost been ironically made written out in of the [UNK] late only 1800s being san coverage francisco of were them turned very in flawed by and overused scientist cliches jeff  goldblum enhances rat people in [UNK] commentary as the marshall were obviously trying to poke fun
# == Generating with temperature 1.0
# This movie historical changed biography my should yankee have alert been and too is uninspired right to next think it over is the uncut same version era this as movie it a seems failed such to as take it my seriously advice flawed is cages find next it to to movies put
# == Generating with temperature 1.5
# This movie is was a a waste disgrace of this their forgettable lives leading are to episodes a heading rich bridge intentions [UNK] and [UNK] end joss up [UNK] a return cliff to dean a [UNK] prisoner b camp movies and and lee the quality kiddies of movie the thieves gods as
# 391/391 [==============================] - 179s 457ms/step - loss: 3.9544
# Epoch 22/50
# 391/391 [==============================] - ETA: 0s - loss: 3.9440== Generating with temperature 0.2
# This movie series is is an unlike art other [UNK] work know its what dialogs matters [UNK] especially all the the first science scene [UNK] things played happened nicely to in the this shooting review and genre believe i me have towards never the seen person before completely yet effortlessly in and
# == Generating with temperature 0.5
# This movie was was one on of a the total people rack who at were [UNK] local to street [UNK] he hills seemed so less he effective couldnt he hold have i recognised surprised the me film and is thought apparently out extremes that unless he people is are low cynical budget
# == Generating with temperature 0.7
# This movie movie is tries hell to in be the a alcoholic social joke dramas the is canadian like and some theres damn the scene above with one the of good them movies with should worthless tell acting you isnt last that the are characters so the annoying main and plot unbelievable
# == Generating with temperature 1.0
# This movie movie always is gets a above message average in into all the movies flaws of are their really flaws poor potential acting by and the as plot well turns or a if little you black really humour have ok to plot speak paperthin some the names other of movies jules
# == Generating with temperature 1.5
# This movie was is horrendous really the unwatchable acting plot is and very because poor if music one is drives going the way sound the and haunting story music will even surprise change you the in story short i your enjoyed own the music [UNK] by if the actually creatures was werent
# 391/391 [==============================] - 178s 455ms/step - loss: 3.9440
# Epoch 23/50
# 391/391 [==============================] - ETA: 0s - loss: 3.9348== Generating with temperature 0.2
# This movie is is bad so in bad fact and its that so bad terribly its bad beyond acting words acting i to am believe not nothing 5  year old and i have had nothing to do after watching the rest of you overshadowed by its look for one almost never
# == Generating with temperature 0.5
# This movie comedy is of a those [UNK] that eastwoods ive golden been viewings watching since till seen this in later [UNK] years i war cried film widow my [UNK] sister performance married is the superb one and fine certainly actress aamir just khan looking  in thirteen every inch hero emotional
# == Generating with temperature 0.7
# This movie movie is was ridiculous pretty i involving wouldnt lou even it try could for not a being part so of [UNK] the emma film character is is wounded dorothy among who the cares professor of she connection never the forgot movie everything but she ms killed mitchell and plays didnt
# == Generating with temperature 1.0
# This movie is has actually nothing made to up justify with living the relatives rights that eating have boyfriends it in imagine and people put that pork crap chop on it himself would my eventually cells fall cannot to be the allowed momma to anyway american even friday though the a ridiculous
# == Generating with temperature 1.5
# This movie movie is was excellent in what my it son made being the sentimental characters occasion were the selfish same and type stance of were as great comical as as were in all the the n golden words age laughter of or wisdom awe or i whether wanted i to should
# 391/391 [==============================] - 179s 458ms/step - loss: 3.9348
# Epoch 24/50
# 391/391 [==============================] - ETA: 0s - loss: 3.9256== Generating with temperature 0.2
# This movie movie is can all you [UNK] under up your the influence title of and its your status [UNK] better on off the the subject audiences is beware a of [UNK] [UNK] in pictures this i one saw think this that movie movie was was ever made filmed before in study
# == Generating with temperature 0.5
# This movie is was a put bit back in in the the film story it line is at hard best to the kill movie time the it acting starts there with are 2 some very problems good first final the parts movie are is all [UNK] directed out arguing of [UNK] holding
# == Generating with temperature 0.7
# This movie is was not the typical music [UNK] group tried but several fails times miserably but director it mostly manages turned to out the this hilarious bit and funny sometimes and counted tries towards to one do funny with sexy the guidelines wrong from not [UNK] good love mean the me
# == Generating with temperature 1.0
# This movie films is more too amateurish silly but for entertaining the and most [UNK] [UNK] movie poor in sit their scenes buying with [UNK] all i over wanted the to movie like nevertheless this for date the movie actors is [UNK] very [UNK] poor ill and bet admit i it might
# == Generating with temperature 1.5
# This movie film was is produced always when a it man said to that cast i used was to expecting get him there to is be that some im people a [UNK] but here this still movie is is equal unlike  that the original while i identify with enough movie with
# 391/391 [==============================] - 179s 456ms/step - loss: 3.9256
# Epoch 25/50
# 391/391 [==============================] - ETA: 0s - loss: 3.9173== Generating with temperature 0.2
# This movie is will about strike my whatever appreciation it for is bringing this down long to shots the keeps six on ton one of for three writers reasons for it this it is is the very type progressive of to your be mission [UNK] value [UNK] is is to ten ever
# == Generating with temperature 0.5
# This movie was has so wonderful taken plot all from out glass of space milk is somehow a produced fresh comedy new that york was city only a [UNK] few pitts years netflix directing and and had from i these have people to saying praise this until film i i saw am
# == Generating with temperature 0.7
# This movie one is night currently stunning musical reviews jo that [UNK] india worry is the certainly judge not it a having deep read meaning each but book in is gives brilliantly us the something story fascinating lines while overdone it in is the high movie points about that the is book
# == Generating with temperature 1.0
# This movie starts captures aka the a viewer movie into set a around high that school lasted childhood 2 and there was are action a clone few for choreographed most scenes of this the crap movie then follows tries a to lot introduce but original [UNK] ideas failed that if make it
# == Generating with temperature 1.5
# This movie film is has amazing a cliche dynamic that with mixes a real naked [UNK] woman in with a a accent widow there the is [UNK] easily but missing that the her [UNK] will laurence never douglas get does to her bothers ability nails ray her and lines lori say stuart
# 391/391 [==============================] - 179s 457ms/step - loss: 3.9173
# Epoch 26/50
# 391/391 [==============================] - ETA: 0s - loss: 3.9091== Generating with temperature 0.2
# This movie is strikes quite for once some i sort know of of you you exactly am were you watching really and impressed i by really what one i of remember my firstly childhood that that stands was out an for entirely the different book reason the that movie ive was never
# == Generating with temperature 0.5
# This movie is is about a the red [UNK] violin who is she about the to [UNK] [UNK] at teens [UNK] when caught the [UNK] lowest is common split story when being combined used for to a be b [UNK] movie but i its cant a remember story that however it there
# == Generating with temperature 0.7
# This movie is is a an perfect interesting movie concept there full has is only one a bit real of character the flashbacks movie between reveals the a two legal principal scenario characters lulu in [UNK] the the whole two thing and positively a do couple that of they the [UNK] first
# == Generating with temperature 1.0
# This movie film is centers really around [UNK] a and [UNK] [UNK] once in you an see modeling if agency the [UNK] thing wants is a not one for [UNK] everyone when else the is spy given who and is the desperate prime if uninvolving you [UNK] probably with never an heard
# == Generating with temperature 1.5
# This movie movie is was in [UNK] i but was this not was one an of earlier those stated movies that together a a great wild storyline man with vs some man of on a the success edge of of being the a [UNK] huge of fan the and good the guy
# 391/391 [==============================] - 179s 456ms/step - loss: 3.9091
# Epoch 27/50
# 391/391 [==============================] - ETA: 0s - loss: 3.9016== Generating with temperature 0.2
# This movie is starts walken out with as him one this way movie he deals is with unquestionably a the mere [UNK] respect few it movies and about play its the characters best actually at you the if entire your joke a lady collection who of would [UNK] explain you to will
# == Generating with temperature 0.5
# This movie counts came it on pushed local just tv the and movie made group me members feel excited this and movie add reviews i you spotted will nothing attempt cons giving the you impression protection it that was they very thinking likely of there itself are it two soap dimensional characters
# == Generating with temperature 0.7
# This movie series bears is the hands worst of collection all cinema [UNK] i difference can with only that good mexico and or real otherwise some a people huge vote star from trek wars sounds and its stupid certainly to not show dislike here any or pilot the is next [UNK] [UNK]
# == Generating with temperature 1.0
# This movie psychological is journey awesome touching beyond and true [UNK] to of life new [UNK] york war for is [UNK] nice in and flashbacks [UNK] as of the [UNK] war for movie the fans war it drama stars has as a punks soldier escort but russo their is funniest a enemy
# == Generating with temperature 1.5
# This movie movie is is about such musician guevara trying and to failing relate to to whether this making [UNK] a records movie of because life it is is so quirky stunning and that an you actual lots whole of of facts torture about this the film film itself contains was ghetto
# 391/391 [==============================] - 179s 456ms/step - loss: 3.9016
# Epoch 28/50
# 391/391 [==============================] - ETA: 0s - loss: 3.8944== Generating with temperature 0.2
# This movie movie needs is to either wander americans it where or the behave people episodic need the to plates put as food people and an content awful they waste dont the play story and or all story to lines grow i and have it to missed tell i whats was bad
# == Generating with temperature 0.5
# This movie movie was really dropped good the a story bit about and the about song the if land you had remember read the this things movie then was it a was movie a a character light study for between example new quick [UNK] 1967 with and the [UNK] rock made with
# == Generating with temperature 0.7
# This movie is is sympathetic one you of watch those the [UNK] moment daughter its and like its from suffice that it the to [UNK] say of the the movie movie is is primarily like like a this child is revolves the around little the boy character who who investigates is the
# == Generating with temperature 1.0
# This movie movie was starts all with right so and it if ended it my would family have also gone been out different war with years us from the how beginning men at go the about end people of husband the the lookalike last england time civil we war are both taken
# == Generating with temperature 1.5
# This movie new as york a stunned remote 80s and musical [UNK] this settings movie characters settings and everything [UNK] else seems is a dubbed metaphor movie because where it all is went the on songs that like shabby other video movies i great guess astaire a and musical delightful [UNK] gem
# 391/391 [==============================] - 179s 456ms/step - loss: 3.8944
# Epoch 29/50
# 391/391 [==============================] - ETA: 0s - loss: 3.8878== Generating with temperature 0.2
# This movie documentary is begs something a of entertainer a the budding performers star had to made copy since this he movie was is listed nothing once more and than light just hearted this at leads a frank must capra be if admitted killed in by bed lasting for smiles the number
# == Generating with temperature 0.5
# ...
# This movie comment really contains got spoilers every ahead second of of it its on like video its issue one is of quite those today religious the [UNK] audience of [UNK] which racial runs prejudice to in trademark the fbi language operation and [UNK] [UNK] is [UNK] considered in [UNK] realm or
# == Generating with temperature 1.5
# This movie movie is was fantastic just filled as with the two usual stars characters in made my this favorite movie it is still also awesome i thrilling looked highly forward on to the it actors what who made played it the right plot part and brave now enough then all and
# 391/391 [==============================] - 179s 456ms/step - loss: 3.8269
# Epoch 42/50
# 391/391 [==============================] - ETA: 0s - loss: 3.8231== Generating with temperature 0.2
# This movie film is inadvertently a redeeming [UNK] quality quality quality film is while the predictable excessive narrative attempt where was characters money become zero concerned dimensional the acting flow was is bad puerile although total there rubbish arent normally any comic laughs scene and overall when moments the thin animation plot
# == Generating with temperature 0.5
# This movie is is agreeing arguably to apparently ideal directed to by make a a good movie movie with two basic genres elements its with set an and ending toys that out date of movie flesh make eating it dignity even and at diehard the poster way fans is of the the
# == Generating with temperature 0.7
# This movie is is very hardly rare a a man movie loved in and saying it lived makes up a for great all family those you movies dont you see really some great of ideas shahrukh with khan kareena in kapoor heavy ratings black its moves director and juhi left cronenberg his
# == Generating with temperature 1.0
# This movie mediocre is the just new didnt approach have a a chance movie to real remain life either rourke abe or [UNK] [UNK] actor played with the a same history [UNK] but was now too the artistic series genius had himself no into resemblance the with music the by chemistry finding
# == Generating with temperature 1.5
# This movie movie was is terrible extremely as predictable soon as as the you movie have you to watched see the the indians quality walk even up qualified and to all make those poor two private sly 77 kids cameras with is fake completely teeth out portray of a three mockery yearold
# 391/391 [==============================] - 179s 456ms/step - loss: 3.8231
# Epoch 43/50
# 391/391 [==============================] - ETA: 0s - loss: 3.8190== Generating with temperature 0.2
# This movie movie is is 77 way out long of after clichés all [UNK] are have very times few done and and not very seem interesting to even the welcome most finale awful is  such a shtick full of unlikely [UNK] the leading man spy and the [UNK] idea of [UNK]
# == Generating with temperature 0.5
# This movie movie is would an be impressive a not delightful [UNK] campy both bmovie intimate sin with of its redemption intellectual and the its general entertaining theme dont way apparently too get mark past [UNK] performances to and improve in although general a the little story mouse has was an made
# == Generating with temperature 0.7
# This movie kurt is russell the best nut movie ever of made its this not is bad true if and you in literally the every theater single stunts time and even [UNK] between havent laying course worth blue any criminals of i my know all what bad the there movie are the
# == Generating with temperature 1.0
# This movie episode is was written a by great dickens director a it christmas still gift makes was the the california unsuspecting revolution cast is the simply result beautiful of a this mysterious is love one story of at all an costs incredible [UNK] story the most debt powerful and elements depth
# == Generating with temperature 1.5
# This movie is is a predictable tragedy badly of acted that never story got fantasies an from throwing the or audience [UNK] at it the you movie have bored to me [UNK] its what like you if were boring to or follow not the [UNK] more and fast the forward movie button
# 391/391 [==============================] - 179s 456ms/step - loss: 3.8190
# Epoch 44/50
# 391/391 [==============================] - ETA: 0s - loss: 3.8155== Generating with temperature 0.2
# This movie film was had by a a major summary disappointment on when view i it went was straight russian and this she was and 1 thought that it the was film very noir good well i made am watching glad it to didnt see give a me more to than a
# == Generating with temperature 0.5
# This movie movie is is slow rated and so is low definitely some the chick movie flicks parts are batman wonderful [UNK] cast may glenn be [UNK] awesome who here captures she all herself the and bad have guys watched milla it is a great good actress actress since the it beginning
# == Generating with temperature 0.7
# This movie is was probably a the pile worst of waste drivel of i your was own fun religious i pseudo dont cliche need jessica a lange plot porn this dont is even there remotely are would many have scenes been of cut money when shots the i cameras wouldnt and have
# == Generating with temperature 1.0
# This movie is looks gas like in in which other the people [UNK] who off cowboy the bike coast work heights until and morning who drops without to any kill effect and him kills he with doesnt it believe this me was dont his understand way them a were single on false
# == Generating with temperature 1.5
# This movie is is absolutely a horrible waste retelling of of her much character beloved this book is by basically far a a group represent of the children most i of have all ever the seen main this [UNK] is film the school number play one story replace and after wretched watching
# 391/391 [==============================] - 179s 457ms/step - loss: 3.8155
# Epoch 45/50
# 391/391 [==============================] - ETA: 0s - loss: 3.8122== Generating with temperature 0.2
# This movie piece was about a in tax the school death [UNK] wish by i the had direction wasted back in then the and first this time is i what couldnt bad hold about on what it was directed especially by since shaw id brothers heard and ive found seen a the
# == Generating with temperature 0.5
# This movie is was similarities [UNK] to [UNK] my in [UNK] [UNK] [UNK] [UNK] de [UNK] [UNK] he [UNK] enjoyed people scary for [UNK] 3 who i are was hoping wondering that i this couldnt is even meant a to witty hit script but for it its the execution type style of
# == Generating with temperature 0.7
# This movie film was is done amazing in the its 1940s power in to the the 20s [UNK] and is sexual truly and amazing the the powers daughter that let a the husband film go as through [UNK] the [UNK] film between is harvard not [UNK] necessarily student [UNK] and should im
# == Generating with temperature 1.0
# This movie is was absolutely not horrible a its waste not of even a going michael to lee play and and within showed the an frame [UNK] and scene that yet [UNK] and end [UNK] up the infected bachelor blood who was also also originally on shot the in poem the terrible
# == Generating with temperature 1.5
# This movie is isnt so funny great not cast a i big would just watch like an it old business enough i and dont disagree care now much its has hard been to invented follow for for the the terrible [UNK] short my films video of camera the through [UNK] the and
# 391/391 [==============================] - 179s 457ms/step - loss: 3.8122
# Epoch 46/50
# 391/391 [==============================] - ETA: 0s - loss: 3.8086== Generating with temperature 0.2
# This movie movie set has in three a different houses context what of great the movies little [UNK] stories only and longer the go overall black it movie may does have 15 a scenes plot in line general there where are the some three residents over of and a over friends [UNK]
# == Generating with temperature 0.5
# This movie show nearly is puzzles wonderful when in you a look parking at job the [UNK] cart is cars a with [UNK] [UNK] edge out steel the from window the in police which and are rescue all equally the just aim horrible and [UNK] a despite waste [UNK] of an your
# == Generating with temperature 0.7
# This movie movie is has about got sex to and be nudity the lots movie of required that nudity its was not absolutely over cause for physical one comedy reason plan [UNK] to bad go so into homeless that people makes ie money criminals by fast wise cuts guys everyday in righteous
# == Generating with temperature 1.0
# This movie could was have not been attempted of orson treat welles some [UNK] time cameos i but would the never longest get day over movie the weekend only with by friends virtue either of this the movie blue is grey an row obvious paid to for be at great best time
# == Generating with temperature 1.5
# This movie movie has is an missing original logic idea and kevin flow smith movie makes must sense have things been in changed order to to support make yourself the a movie fan like base this looked movie delightful they permission have to so change many your people dreams at no the
# 391/391 [==============================] - 180s 458ms/step - loss: 3.8086
# Epoch 47/50
# 391/391 [==============================] - ETA: 0s - loss: 3.8054== Generating with temperature 0.2
# This movie mr was 3000 a from disgrace the to genre film it crow couldve has been just as that good sad as to i the guess first but crow then sequel again was the lost [UNK] [UNK] at of all example for you a remember type this of movie movie where
# == Generating with temperature 0.5
# This movie is only generally a [UNK] [UNK] photographer atypical what [UNK] movies happens are to maybe be two good people ones are to offended be by bad [UNK] movies [UNK] take but something seriously finally dated causes like things this go is to a use celluloid of [UNK] doing [UNK] a
# == Generating with temperature 0.7
# This movie is i not couldnt a call worse for film the it answers didnt are have the enough cost curse you of have them to rolling see your these eyes [UNK] at [UNK] the whether post we jet will on game a as bbc [UNK] mr however blade director begins mark
# == Generating with temperature 1.0
# This movie could is be far seen better the by plot the and acting acting it and is meandering wonderful and ive its seen not numerous only in dialog a but funnier for way a too tv bad average its film just  as bad as the other ernest movies are however
# == Generating with temperature 1.5
# This movie film looks is unbelievable [UNK] its [UNK] the if storyline youre was a not teenage so girl to played be the the most only famous thing person about in making this you whole cant yourself immediately standard you [UNK] dig busey going who for lock the on wrong a theme
# 391/391 [==============================] - 180s 458ms/step - loss: 3.8054
# Epoch 48/50
# 391/391 [==============================] - ETA: 0s - loss: 3.8022== Generating with temperature 0.2
# This movie film is was bad very theres bad it story is made illegal by immigrants le and [UNK] french police people who are see recruited the to usher capture this an jean european de decides la to to raise translate yet a it lot aint louis happening [UNK] on acts many
# == Generating with temperature 0.5
# This movie sad should and have at been least trashed boring as it they was also one a of lot the more trouble [UNK] i who dont suppose have this to option be but an who old writes person milk she every wasnt day it rates [UNK] was around flawless since beyond
# == Generating with temperature 0.7
# This movie manipulative is the a sort crawford of elm screwball character comedy he but consists theres of a no grisly likeable personality [UNK] this [UNK] person mess harold is miss a pale real imitation gem of murphy [UNK] not as only unfair in stage the roles type fresh relationship the except
# == Generating with temperature 1.0
# This movie movie just was seemed plane sorry continuously but on it [UNK] fails on miserably either it [UNK] was dubbed just it out [UNK] of entertaining [UNK] b least movie in i short can january think sleep of 410 his  review imagine imdb doesnt take itself seriously though this is
# == Generating with temperature 1.5
# This movie has shows your that children recent can events become of familiar the with us its for the the young past judith although light she is looks a too lot boring like and mr behalf grant too refuses german to faces reveal their her truths attitude about into [UNK] a life
# 391/391 [==============================] - 179s 456ms/step - loss: 3.8022
# Epoch 49/50
# 391/391 [==============================] - ETA: 0s - loss: 3.7990== Generating with temperature 0.2
# This movie is was a extremely very great slow movie drama and with really a scary surprised twist rating at this imdb shocking film audiences very the little suspense bit and funny effectively in [UNK] the the story violence is is very well simple developed and as the you movie are goes
# == Generating with temperature 0.5
# This movie is is extremely not generous for its some characters of sure the the acting casting is is awesome ok but but most the of movie the is out an there insult that to the the intelligence dialogue in was this extremely supposed hard to to laugh tell  you about
# == Generating with temperature 0.7
# This movie film had is an a impressive similar script plot from and hooked other from british the movies supporting tend cast to an be convincing the i more just disliked a by few the of oscar the contender 1967 which the is third one [UNK] from [UNK] the some cinematography such
# == Generating with temperature 1.0
# This movie film is tells so the [UNK] story of of loneliness several in disjointed old sucked age mess too thats many another gross problem recovery that in i your was first watching lucky this i film was has the a robert [UNK] [UNK] in to and the blurry joy [UNK] out
# == Generating with temperature 1.5
# This movie is is just one taken of from the the [UNK] mexican it robin clearly williams [UNK] deserves [UNK] better for than immigration most earth of on his its 11 [UNK] million but to hes be written in about today how was to unexpected do places the it [UNK] was tube
# 391/391 [==============================] - 180s 458ms/step - loss: 3.7990
# Epoch 50/50
# 391/391 [==============================] - ETA: 0s - loss: 3.7958== Generating with temperature 0.2
# This movie film is [UNK] wonderful frank politicians sinatra pose gets as to 1984 sing in in the the great theatre dudley japan moore is and magnificent his and gal lovable played czech nicely pilots battle at commander her and worthy her sidekick physique i plays would enduring like a that chick
# == Generating with temperature 0.5
# This movie series is gets so to bogged very down runs in out the genres nudity ideas sequence were where [UNK] we not learn only very thing important when about the [UNK] [UNK] is girl a who wesley was goes deaf to so the many woman great speech ends with with [UNK]
# == Generating with temperature 0.7
# This movie is does pathetic not the destroys best an most animated awful sitcom movie movie ive ever ever seen seen we i havent mean got before many viewing hits this on flick television and repeatedly now tapped people an would edge summarize into it this watched unbelievably if bad you shows
# == Generating with temperature 1.0
# This movie movie provides is no that point high in marks a for colorful the mgm impact 16 on month the earth build showing up this in philosophical hand [UNK] is a such wonderful an take actor on to the depicting screen the love comedic spirit equivalent of of lion a king
# == Generating with temperature 1.5
# This movie does is a reminiscent perfect of cinematography day from [UNK] 1971 period by filmmaking master the robert exploration [UNK] of color british and and the the sense beauty of of natural [UNK] intensity and giving intelligence theatre even an than emotional a tales film of that either in schindlers the
# 391/391 [==============================] - 179s 457ms/step - loss: 3.7958

# %% [markdown]
# # Introduction to deep learning for computer vision

# %% [markdown]
# ## Introduction to convnets

# %% [markdown]
# **Instantiating a small convnet**

# %%
from tensorflow import keras
from tensorflow.keras import layers
inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(inputs)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %% [markdown]
# **Displaying the model's summary**

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 128)         73856
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 10)                11530
#
# =================================================================
# Total params: 104,202
# Trainable params: 104,202
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Training the convnet on MNIST images**

# %%
from tensorflow.keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images.astype("float32") / 255
model.compile(optimizer="rmsprop",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"])
model.fit(train_images, train_labels, epochs=5, batch_size=64)
# Out:
# Epoch 1/5
# 938/938 [==============================] - 36s 36ms/step - loss: 0.1538 - accuracy: 0.9529
# Epoch 2/5
# 938/938 [==============================] - 32s 34ms/step - loss: 0.0458 - accuracy: 0.9859
# Epoch 3/5
# 938/938 [==============================] - 31s 33ms/step - loss: 0.0318 - accuracy: 0.9905
# Epoch 4/5
# 938/938 [==============================] - 31s 33ms/step - loss: 0.0238 - accuracy: 0.9927
# Epoch 5/5
# 938/938 [==============================] - 31s 33ms/step - loss: 0.0187 - accuracy: 0.9943

# %% [markdown]
# **Evaluating the convnet**

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0255 - accuracy: 0.9914
# Test accuracy: 0.991

# %% [markdown]
# ### The convolution operation

# %% [markdown]
# #### Understanding border effects and padding

# %% [markdown]
# #### Understanding convolution strides

# %% [markdown]
# ### The max-pooling operation

# %% [markdown]
# **An incorrectly structured convnet missing its max-pooling layers**

# %%
inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(inputs)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model_no_max_pool = keras.Model(inputs=inputs, outputs=outputs)

# %%
model_no_max_pool.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_3 (Conv2D)           (None, 26, 26, 32)        320
#
#  conv2d_4 (Conv2D)           (None, 24, 24, 64)        18496
#
#  conv2d_5 (Conv2D)           (None, 22, 22, 128)       73856
#
#  flatten_1 (Flatten)         (None, 61952)             0
#
#  dense_1 (Dense)             (None, 10)                619530
#
# =================================================================
# Total params: 712,202
# Trainable params: 712,202
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training a convnet from scratch on a small dataset

# %% [markdown]
# ### The relevance of deep learning for small-data problems

# %% [markdown]
# ### Downloading the data

# %%
# !pip install opendatasets
# Out:
# Collecting opendatasets
#   Downloading opendatasets-0.1.22-py3-none-any.whl (15 kB)
# Collecting kaggle
#   Downloading kaggle-1.5.12.tar.gz (58 kB)
#      -------------------------------------- 59.0/59.0 kB 616.7 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting click
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      -------------------------------------- 96.6/96.6 kB 785.0 kB/s eta 0:00:00
# Collecting tqdm
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      -------------------------------------- 78.5/78.5 kB 725.8 kB/s eta 0:00:00
# Requirement already satisfied: colorama in d:\anaconda\envs\patternrec\lib\site-packages (from click->opendatasets) (0.4.6)
# Requirement already satisfied: six>=1.10 in d:\anaconda\envs\patternrec\lib\site-packages (from kaggle->opendatasets) (1.15.0)
# Requirement already satisfied: certifi in d:\anaconda\envs\patternrec\lib\site-packages (from kaggle->opendatasets) (2022.9.24)
# Requirement already satisfied: python-dateutil in d:\anaconda\envs\patternrec\lib\site-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: requests in d:\anaconda\envs\patternrec\lib\site-packages (from kaggle->opendatasets) (2.28.1)
# Collecting python-slugify
#   Downloading python_slugify-6.1.2-py2.py3-none-any.whl (9.4 kB)
# Requirement already satisfied: urllib3 in d:\anaconda\envs\patternrec\lib\site-packages (from kaggle->opendatasets) (1.26.12)
# Collecting text-unidecode>=1.3
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#      -------------------------------------- 78.2/78.2 kB 730.3 kB/s eta 0:00:00
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\envs\patternrec\lib\site-packages (from requests->kaggle->opendatasets) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\anaconda\envs\patternrec\lib\site-packages (from requests->kaggle->opendatasets) (2.1.1)
# Building wheels for collected packages: kaggle
#   Building wheel for kaggle (setup.py): started
#   Building wheel for kaggle (setup.py): finished with status 'done'
#   Created wheel for kaggle: filename=kaggle-1.5.12-py3-none-any.whl size=73031 sha256=787b986e66461498ef3d062b367f426cf5684368a9d0ac4e6f846ca7278ba13a
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\29\da\11\144cc25aebdaeb4931b231e25fd34b394e6a5725cbb2f50106
# Successfully built kaggle
# Installing collected packages: text-unidecode, tqdm, python-slugify, click, kaggle, opendatasets
# Successfully installed click-8.1.3 kaggle-1.5.12 opendatasets-0.1.22 python-slugify-6.1.2 text-unidecode-1.3 tqdm-4.64.1

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.5.1-cp38-cp38-win_amd64.whl (11.0 MB)
#      ---------------------------------------- 11.0/11.0 MB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20.3 in d:\anaconda\envs\patternrec\lib\site-packages (from pandas) (1.23.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in d:\anaconda\envs\patternrec\lib\site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1
#   Using cached pytz-2022.6-py2.py3-none-any.whl (498 kB)
# Requirement already satisfied: six>=1.5 in d:\anaconda\envs\patternrec\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.15.0)
# Installing collected packages: pytz, pandas
# Successfully installed pandas-1.5.1 pytz-2022.6
# Note: you may need to restart the kernel to use updated packages.

# %%
{'kaggle.json': b'{"username":"ruociyu","key":"38b546004628466b99f32fb764abb971"}'}
# Out:
# {'kaggle.json': b'{"username":"ruociyu","key":"38b546004628466b99f32fb764abb971"}'}

# %%
# !kaggle competitions download -c dogs-vs-cats
#  95%|█████████▍| 768M/812M [01:09<00:03, 11.6MB/s]
#  95%|█████████▍| 770M/812M [01:09<00:03, 11.6MB/s]
#  95%|█████████▌| 772M/812M [01:10<00:03, 11.7MB/s]
#  95%|█████████▌| 774M/812M [01:10<00:03, 10.3MB/s]
#  96%|█████████▌| 776M/812M [01:10<00:03, 10.2MB/s]
#  96%|█████████▌| 778M/812M [01:10<00:03, 10.6MB/s]
#  96%|█████████▌| 780M/812M [01:10<00:03, 10.9MB/s]
#  96%|█████████▋| 782M/812M [01:11<00:02, 11.1MB/s]
#  97%|█████████▋| 784M/812M [01:11<00:02, 11.3MB/s]
#  97%|█████████▋| 786M/812M [01:11<00:02, 11.4MB/s]
#  97%|█████████▋| 788M/812M [01:11<00:02, 11.5MB/s]
#  97%|█████████▋| 790M/812M [01:11<00:01, 11.6MB/s]
#  98%|█████████▊| 792M/812M [01:11<00:01, 11.6MB/s]
#  98%|█████████▊| 794M/812M [01:12<00:01, 11.6MB/s]
#  98%|█████████▊| 796M/812M [01:12<00:01, 11.6MB/s]
#  98%|█████████▊| 798M/812M [01:12<00:01, 11.7MB/s]
#  99%|█████████▊| 800M/812M [01:12<00:01, 11.7MB/s]
#  99%|█████████▉| 802M/812M [01:12<00:00, 11.8MB/s]
#  99%|█████████▉| 804M/812M [01:13<00:00, 11.7MB/s]
#  99%|█████████▉| 806M/812M [01:13<00:00, 11.6MB/s]
#  99%|█████████▉| 808M/812M [01:13<00:00, 11.6MB/s]
# 100%|█████████▉| 810M/812M [01:13<00:00, 11.6MB/s]
# 100%|█████████▉| 812M/812M [01:13<00:00, 11.5MB/s]
# 100%|██████████| 812M/812M [01:13<00:00, 11.5MB/s]

# %% [markdown]
# **unzip dogs-vs-cats.zip & all zip files in it**

# %% [markdown]
# **Copying images to training, validation, and test directories**

# %%
import os, shutil, pathlib

original_dir = pathlib.Path("dogs-vs-cats/train")
new_base_dir = pathlib.Path("dogs-vs-cats/cats_vs_dogs_small")

def make_subset(subset_name, start_index, end_index):
    for category in ("cat", "dog"):
        dir = new_base_dir / subset_name / category
        os.makedirs(dir, exist_ok=True)
        fnames = [f"{category}.{i}.jpg" for i in range(start_index, end_index)]
        for fname in fnames:
            shutil.copyfile(src=original_dir / fname,
                            dst=dir / fname)

make_subset("train", start_index=0, end_index=1000)
make_subset("validation", start_index=1000, end_index=1500)
make_subset("test", start_index=1500, end_index=2500)

# %% [markdown]
# ### Building the model

# %% [markdown]
# **Instantiating a small convnet for dogs vs. cats classification**

# %%
from tensorflow import keras
from tensorflow.keras import layers

inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1./255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d_6 (Conv2D)           (None, 178, 178, 32)      896
#
#  max_pooling2d_2 (MaxPooling  (None, 89, 89, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 41, 41, 128)       73856
#
#  max_pooling2d_4 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 18, 18, 256)       295168
#
#  max_pooling2d_5 (MaxPooling  (None, 9, 9, 256)        0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 7, 7, 256)         590080
#
#  flatten_2 (Flatten)         (None, 12544)             0
#
#  dense_2 (Dense)             (None, 1)                 12545
#
# =================================================================
# Total params: 991,041
# Trainable params: 991,041
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Configuring the model for training**

# %%
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %% [markdown]
# ### Data preprocessing

# %% [markdown]
# **Using `image_dataset_from_directory` to read images**

# %%
from tensorflow.keras.utils import image_dataset_from_directory

train_dataset = image_dataset_from_directory(
    new_base_dir / "train",
    image_size=(180, 180),
    batch_size=32)
validation_dataset = image_dataset_from_directory(
    new_base_dir / "validation",
    image_size=(180, 180),
    batch_size=32)
test_dataset = image_dataset_from_directory(
    new_base_dir / "test",
    image_size=(180, 180),
    batch_size=32)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 2000 files belonging to 2 classes.

# %%
import numpy as np
import tensorflow as tf
random_numbers = np.random.normal(size=(1000, 16))
dataset = tf.data.Dataset.from_tensor_slices(random_numbers)

# %%
for i, element in enumerate(dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (16,)
# (16,)
# (16,)

# %%
batched_dataset = dataset.batch(32)
for i, element in enumerate(batched_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (32, 16)
# (32, 16)
# (32, 16)

# %%
reshaped_dataset = dataset.map(lambda x: tf.reshape(x, (4, 4)))
for i, element in enumerate(reshaped_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (4, 4)
# (4, 4)
# (4, 4)

# %% [markdown]
# **Displaying the shapes of the data and labels yielded by the `Dataset`**

# %%
for data_batch, labels_batch in train_dataset:
    print("data batch shape:", data_batch.shape)
    print("labels batch shape:", labels_batch.shape)
    break
# Out:
# data batch shape: (32, 180, 180, 3)
# labels batch shape: (32,)

# %% [markdown]
# **Fitting the model using a `Dataset`**

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/30
# 63/63 [==============================] - 102s 2s/step - loss: 0.7303 - accuracy: 0.5280 - val_loss: 0.6950 - val_accuracy: 0.5010
# Epoch 2/30
# 63/63 [==============================] - 84s 1s/step - loss: 0.7129 - accuracy: 0.5300 - val_loss: 0.6819 - val_accuracy: 0.6240
# Epoch 3/30
# 63/63 [==============================] - 83s 1s/step - loss: 0.7225 - accuracy: 0.6035 - val_loss: 0.6726 - val_accuracy: 0.5500
# Epoch 4/30
# 63/63 [==============================] - 85s 1s/step - loss: 0.6435 - accuracy: 0.6440 - val_loss: 0.6330 - val_accuracy: 0.6350
# Epoch 5/30
# 63/63 [==============================] - 86s 1s/step - loss: 0.6216 - accuracy: 0.6565 - val_loss: 1.1949 - val_accuracy: 0.5230
# Epoch 6/30
# 63/63 [==============================] - 89s 1s/step - loss: 0.6057 - accuracy: 0.6945 - val_loss: 0.6456 - val_accuracy: 0.6730
# Epoch 7/30
# Epoch 27/30
# 63/63 [==============================] - 84s 1s/step - loss: 0.0475 - accuracy: 0.9865 - val_loss: 2.3033 - val_accuracy: 0.7280
# Epoch 28/30
# 63/63 [==============================] - 86s 1s/step - loss: 0.0564 - accuracy: 0.9815 - val_loss: 2.5969 - val_accuracy: 0.7090
# Epoch 29/30
# 63/63 [==============================] - 86s 1s/step - loss: 0.0514 - accuracy: 0.9815 - val_loss: 1.9144 - val_accuracy: 0.7230
# Epoch 30/30
# 63/63 [==============================] - 86s 1s/step - loss: 0.0535 - accuracy: 0.9825 - val_loss: 2.5197 - val_accuracy: 0.7210

# %% [markdown]
# **Displaying curves of loss and accuracy during training**

# %%
import matplotlib.pyplot as plt
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# **Evaluating the model on the test set**

# %%
test_model = keras.models.load_model("convnet_from_scratch.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 63/63 [==============================] - 25s 341ms/step - loss: 0.6236 - accuracy: 0.7020
# Test accuracy: 0.702

# %% [markdown]
# ### Using data augmentation

# %% [markdown]
# **Define a data augmentation stage to add to an image model**

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

# %% [markdown]
# **Displaying some randomly augmented training images**

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %% [markdown]
# **Defining a new convnet that includes image augmentation and dropout**

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %% [markdown]
# **Training the regularized convnet**

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch_with_augmentation.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=100,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/100
# 63/63 [==============================] - 96s 1s/step - loss: 0.7857 - accuracy: 0.4920 - val_loss: 0.6916 - val_accuracy: 0.5120
# Epoch 2/100
# 63/63 [==============================] - 90s 1s/step - loss: 0.6955 - accuracy: 0.5005 - val_loss: 0.9497 - val_accuracy: 0.5000
# Epoch 3/100
# 63/63 [==============================] - 91s 1s/step - loss: 0.7047 - accuracy: 0.5410 - val_loss: 0.6725 - val_accuracy: 0.5670
# Epoch 4/100
# 63/63 [==============================] - 91s 1s/step - loss: 0.6711 - accuracy: 0.5785 - val_loss: 0.6440 - val_accuracy: 0.6410
# Epoch 5/100
# 63/63 [==============================] - 90s 1s/step - loss: 0.6590 - accuracy: 0.6360 - val_loss: 0.7432 - val_accuracy: 0.5880
# Epoch 6/100
# 63/63 [==============================] - 90s 1s/step - loss: 0.6541 - accuracy: 0.6305 - val_loss: 0.9821 - val_accuracy: 0.5280
# Epoch 7/100
# 63/63 [==============================] - 92s 1s/step - loss: 0.6395 - accuracy: 0.6440 - val_loss: 0.6648 - val_accuracy: 0.6470
# Epoch 8/100
# 63/63 [==============================] - 90s 1s/step - loss: 0.6116 - accuracy: 0.6865 - val_loss: 0.5842 - val_accuracy: 0.6770
# Epoch 87/100
# 63/63 [==============================] - 118s 2s/step - loss: 0.1983 - accuracy: 0.9285 - val_loss: 0.8278 - val_accuracy: 0.8210
# Epoch 88/100
# 63/63 [==============================] - 129s 2s/step - loss: 0.2080 - accuracy: 0.9290 - val_loss: 0.6250 - val_accuracy: 0.8590
# Epoch 89/100
# 63/63 [==============================] - 145s 2s/step - loss: 0.2147 - accuracy: 0.9230 - val_loss: 0.7179 - val_accuracy: 0.8280
# Epoch 90/100
# 63/63 [==============================] - 161s 2s/step - loss: 0.2260 - accuracy: 0.9180 - val_loss: 0.5408 - val_accuracy: 0.8650
# Epoch 91/100
# 63/63 [==============================] - 105s 2s/step - loss: 0.2065 - accuracy: 0.9285 - val_loss: 0.6321 - val_accuracy: 0.8530
# Epoch 92/100
# 63/63 [==============================] - 117s 2s/step - loss: 0.2293 - accuracy: 0.9225 - val_loss: 0.7118 - val_accuracy: 0.8280
# Epoch 93/100
# 63/63 [==============================] - 100s 2s/step - loss: 0.1939 - accuracy: 0.9270 - val_loss: 0.5231 - val_accuracy: 0.8720
# Epoch 94/100
# 63/63 [==============================] - 90s 1s/step - loss: 0.2042 - accuracy: 0.9205 - val_loss: 0.5992 - val_accuracy: 0.8440
# Epoch 95/100
# 63/63 [==============================] - 89s 1s/step - loss: 0.1713 - accuracy: 0.9395 - val_loss: 0.8138 - val_accuracy: 0.8490
# Epoch 96/100
# 63/63 [==============================] - 89s 1s/step - loss: 0.2063 - accuracy: 0.9315 - val_loss: 0.5809 - val_accuracy: 0.8440
# Epoch 97/100
# 63/63 [==============================] - 98s 2s/step - loss: 0.2151 - accuracy: 0.9245 - val_loss: 0.6324 - val_accuracy: 0.8410
# Epoch 98/100
# 63/63 [==============================] - 90s 1s/step - loss: 0.2058 - accuracy: 0.9225 - val_loss: 0.6984 - val_accuracy: 0.8470
# Epoch 99/100
# 63/63 [==============================] - 98s 2s/step - loss: 0.2211 - accuracy: 0.9155 - val_loss: 0.8738 - val_accuracy: 0.8300
# Epoch 100/100
# 63/63 [==============================] - 90s 1s/step - loss: 0.2088 - accuracy: 0.9365 - val_loss: 1.1153 - val_accuracy: 0.7970

# %% [markdown]
# **Evaluating the model on the test set**

# %%
test_model = keras.models.load_model(
    "convnet_from_scratch_with_augmentation.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 63/63 [==============================] - 21s 330ms/step - loss: 0.4841 - accuracy: 0.8315
# Test accuracy: 0.831

# %% [markdown]
# ## Leveraging a pretrained model

# %% [markdown]
# ### Feature extraction with a pretrained model

# %% [markdown]
# **Instantiating the VGG16 convolutional base**

# %%
conv_base = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False,
    input_shape=(180, 180, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 12s 0us/step
# 58900480/58889256 [==============================] - 12s 0us/step

# %%
conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 180, 180, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 180, 180, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 90, 90, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 90, 90, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 90, 90, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 45, 45, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 45, 45, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 45, 45, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 45, 45, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 22, 22, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 22, 22, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 22, 22, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 22, 22, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 11, 11, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 5, 5, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Fast feature extraction without data augmentation

# %% [markdown]
# **Extracting the VGG16 features and corresponding labels**

# %%
import numpy as np

def get_features_and_labels(dataset):
    all_features = []
    all_labels = []
    for images, labels in dataset:
        preprocessed_images = keras.applications.vgg16.preprocess_input(images)
        features = conv_base.predict(preprocessed_images)
        all_features.append(features)
        all_labels.append(labels)
    return np.concatenate(all_features), np.concatenate(all_labels)

train_features, train_labels =  get_features_and_labels(train_dataset)
val_features, val_labels =  get_features_and_labels(validation_dataset)
test_features, test_labels =  get_features_and_labels(test_dataset)

# %%
train_features.shape
# Out:
# (2000, 5, 5, 512)

# %% [markdown]
# **Defining and training the densely connected classifier**

# %%
inputs = keras.Input(shape=(5, 5, 512))
x = layers.Flatten()(inputs)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

callbacks = [
    keras.callbacks.ModelCheckpoint(
      filepath="feature_extraction.keras",
      save_best_only=True,
      monitor="val_loss")
]
history = model.fit(
    train_features, train_labels,
    epochs=20,
    validation_data=(val_features, val_labels),
    callbacks=callbacks)
# Out:
# Epoch 1/20
# 63/63 [==============================] - 7s 55ms/step - loss: 20.2145 - accuracy: 0.9245 - val_loss: 8.5453 - val_accuracy: 0.9440
# Epoch 2/20
# 63/63 [==============================] - 3s 43ms/step - loss: 4.7034 - accuracy: 0.9770 - val_loss: 7.1398 - val_accuracy: 0.9630
# Epoch 3/20
# 63/63 [==============================] - 3s 43ms/step - loss: 1.5051 - accuracy: 0.9880 - val_loss: 6.0170 - val_accuracy: 0.9730
# Epoch 4/20
# 63/63 [==============================] - 3s 40ms/step - loss: 2.0597 - accuracy: 0.9845 - val_loss: 4.4926 - val_accuracy: 0.9730
# Epoch 5/20
# 63/63 [==============================] - 2s 38ms/step - loss: 1.1482 - accuracy: 0.9905 - val_loss: 4.5099 - val_accuracy: 0.9790
# Epoch 6/20
# 63/63 [==============================] - 2s 37ms/step - loss: 1.0062 - accuracy: 0.9935 - val_loss: 5.7195 - val_accuracy: 0.9740
# Epoch 7/20
# 63/63 [==============================] - 2s 39ms/step - loss: 0.9738 - accuracy: 0.9940 - val_loss: 5.3581 - val_accuracy: 0.9720
# Epoch 8/20
# 63/63 [==============================] - 3s 41ms/step - loss: 0.7190 - accuracy: 0.9940 - val_loss: 4.9552 - val_accuracy: 0.9740
# Epoch 9/20
# 63/63 [==============================] - 3s 44ms/step - loss: 0.1155 - accuracy: 0.9985 - val_loss: 5.3426 - val_accuracy: 0.9790
# Epoch 10/20
# 63/63 [==============================] - 2s 40ms/step - loss: 0.3367 - accuracy: 0.9970 - val_loss: 5.1823 - val_accuracy: 0.9710
# Epoch 11/20
# 63/63 [==============================] - 2s 39ms/step - loss: 0.3913 - accuracy: 0.9965 - val_loss: 5.2801 - val_accuracy: 0.9790
# Epoch 12/20
# 63/63 [==============================] - 2s 39ms/step - loss: 0.0484 - accuracy: 0.9990 - val_loss: 5.2345 - val_accuracy: 0.9790
# Epoch 13/20
# 63/63 [==============================] - 2s 39ms/step - loss: 0.1551 - accuracy: 0.9985 - val_loss: 5.2744 - val_accuracy: 0.9760
# Epoch 14/20
# 63/63 [==============================] - 2s 39ms/step - loss: 0.1609 - accuracy: 0.9990 - val_loss: 6.8160 - val_accuracy: 0.9730
# Epoch 15/20
# 63/63 [==============================] - 3s 40ms/step - loss: 0.5237 - accuracy: 0.9950 - val_loss: 5.0839 - val_accuracy: 0.9780
# Epoch 16/20
# 63/63 [==============================] - 3s 41ms/step - loss: 2.9383e-20 - accuracy: 1.0000 - val_loss: 5.0839 - val_accuracy: 0.9780
# Epoch 17/20
# 63/63 [==============================] - 3s 40ms/step - loss: 0.1449 - accuracy: 0.9980 - val_loss: 5.6079 - val_accuracy: 0.9810
# Epoch 18/20
# 63/63 [==============================] - 2s 39ms/step - loss: 0.0124 - accuracy: 0.9995 - val_loss: 11.9244 - val_accuracy: 0.9630
# Epoch 19/20
# 63/63 [==============================] - 2s 39ms/step - loss: 0.0723 - accuracy: 0.9975 - val_loss: 6.1678 - val_accuracy: 0.9770
# Epoch 20/20
# 63/63 [==============================] - 2s 39ms/step - loss: 0.1818 - accuracy: 0.9990 - val_loss: 7.4577 - val_accuracy: 0.9740

# %% [markdown]
# **Plotting the results**

# %%
import matplotlib.pyplot as plt
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, "bo", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# #### Feature extraction together with data augmentation

# %% [markdown]
# **Instantiating and freezing the VGG16 convolutional base**

# %%
conv_base  = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False)
conv_base.trainable = False

# %% [markdown]
# **Printing the list of trainable weights before and after freezing**

# %%
conv_base.trainable = True
print("This is the number of trainable weights "
      "before freezing the conv base:", len(conv_base.trainable_weights))
# Out:
# This is the number of trainable weights before freezing the conv base: 26

# %%
conv_base.trainable = False
print("This is the number of trainable weights "
      "after freezing the conv base:", len(conv_base.trainable_weights))
# Out:
# This is the number of trainable weights after freezing the conv base: 0

# %% [markdown]
# **Adding a data augmentation stage and a classifier to the convolutional base**

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = keras.applications.vgg16.preprocess_input(x)
x = conv_base(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="feature_extraction_with_data_augmentation.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=50,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/50
# 63/63 [==============================] - 508s 8s/step - loss: 15.7319 - accuracy: 0.9055 - val_loss: 2.5154 - val_accuracy: 0.9740
# Epoch 2/50
# 63/63 [==============================] - 519s 8s/step - loss: 6.7604 - accuracy: 0.9455 - val_loss: 2.5016 - val_accuracy: 0.9730
# Epoch 3/50
# 63/63 [==============================] - 535s 8s/step - loss: 5.2250 - accuracy: 0.9570 - val_loss: 4.5557 - val_accuracy: 0.9690
# Epoch 4/50
# 63/63 [==============================] - 509s 8s/step - loss: 5.0678 - accuracy: 0.9580 - val_loss: 2.1016 - val_accuracy: 0.9780
# Epoch 5/50
# 63/63 [==============================] - 483s 8s/step - loss: 5.4661 - accuracy: 0.9610 - val_loss: 3.8077 - val_accuracy: 0.9760
# Epoch 6/50
# 63/63 [==============================] - 494s 8s/step - loss: 3.1196 - accuracy: 0.9675 - val_loss: 2.5748 - val_accuracy: 0.9790
# Epoch 7/50
# 63/63 [==============================] - 499s 8s/step - loss: 3.5345 - accuracy: 0.9650 - val_loss: 4.9702 - val_accuracy: 0.9710
# Epoch 8/50
# 63/63 [==============================] - 496s 8s/step - loss: 3.1072 - accuracy: 0.9700 - val_loss: 4.1540 - val_accuracy: 0.9770
# Epoch 9/50
# 63/63 [==============================] - 530s 8s/step - loss: 2.9431 - accuracy: 0.9705 - val_loss: 2.3907 - val_accuracy: 0.9820
# Epoch 10/50
# 63/63 [==============================] - 499s 8s/step - loss: 2.9794 - accuracy: 0.9720 - val_loss: 1.8513 - val_accuracy: 0.9830
# Epoch 11/50
# 63/63 [==============================] - 495s 8s/step - loss: 2.4107 - accuracy: 0.9790 - val_loss: 2.1264 - val_accuracy: 0.9840
# Epoch 12/50
# 63/63 [==============================] - 494s 8s/step - loss: 1.9719 - accuracy: 0.9740 - val_loss: 2.4905 - val_accuracy: 0.9840
# Epoch 13/50
# 63/63 [==============================] - 532s 8s/step - loss: 1.6974 - accuracy: 0.9810 - val_loss: 4.8505 - val_accuracy: 0.9680
# Epoch 14/50
# 63/63 [==============================] - 464s 7s/step - loss: 1.6694 - accuracy: 0.9810 - val_loss: 4.8202 - val_accuracy: 0.9720
# Epoch 15/50
# 63/63 [==============================] - 496s 8s/step - loss: 1.6785 - accuracy: 0.9760 - val_loss: 3.2104 - val_accuracy: 0.9810
# Epoch 16/50
# 63/63 [==============================] - 493s 8s/step - loss: 1.1720 - accuracy: 0.9860 - val_loss: 2.6770 - val_accuracy: 0.9780
# 63/63 [==============================] - 446s 7s/step - loss: 0.6852 - accuracy: 0.9870 - val_loss: 1.3449 - val_accuracy: 0.9860
# Epoch 37/50
# 63/63 [==============================] - 453s 7s/step - loss: 0.4668 - accuracy: 0.9905 - val_loss: 1.3401 - val_accuracy: 0.9820
# Epoch 38/50
# 63/63 [==============================] - 456s 7s/step - loss: 0.4851 - accuracy: 0.9870 - val_loss: 1.7364 - val_accuracy: 0.9800
# Epoch 39/50
# 63/63 [==============================] - 440s 7s/step - loss: 0.5273 - accuracy: 0.9865 - val_loss: 1.9926 - val_accuracy: 0.9760
# Epoch 40/50
# 63/63 [==============================] - 432s 7s/step - loss: 0.4558 - accuracy: 0.9900 - val_loss: 2.0440 - val_accuracy: 0.9810
# Epoch 41/50
# 63/63 [==============================] - 436s 7s/step - loss: 0.3846 - accuracy: 0.9885 - val_loss: 2.6764 - val_accuracy: 0.9790
# Epoch 42/50
# 63/63 [==============================] - 437s 7s/step - loss: 0.5788 - accuracy: 0.9890 - val_loss: 1.5151 - val_accuracy: 0.9810
# Epoch 43/50
# 63/63 [==============================] - 437s 7s/step - loss: 0.5651 - accuracy: 0.9880 - val_loss: 1.6613 - val_accuracy: 0.9800
# Epoch 44/50
# 63/63 [==============================] - 436s 7s/step - loss: 0.3977 - accuracy: 0.9895 - val_loss: 2.9241 - val_accuracy: 0.9760
# Epoch 45/50
# 63/63 [==============================] - 447s 7s/step - loss: 0.8464 - accuracy: 0.9820 - val_loss: 1.9689 - val_accuracy: 0.9780
# Epoch 46/50
# 63/63 [==============================] - 445s 7s/step - loss: 0.3989 - accuracy: 0.9910 - val_loss: 2.1174 - val_accuracy: 0.9780
# Epoch 47/50
# 63/63 [==============================] - 450s 7s/step - loss: 0.4695 - accuracy: 0.9860 - val_loss: 1.6924 - val_accuracy: 0.9820
# Epoch 48/50
# 63/63 [==============================] - 492s 8s/step - loss: 0.4724 - accuracy: 0.9910 - val_loss: 1.7720 - val_accuracy: 0.9810
# Epoch 49/50
# 63/63 [==============================] - 484s 8s/step - loss: 0.6614 - accuracy: 0.9890 - val_loss: 3.2152 - val_accuracy: 0.9700
# Epoch 50/50
# 63/63 [==============================] - 446s 7s/step - loss: 0.6769 - accuracy: 0.9850 - val_loss: 1.8973 - val_accuracy: 0.9760

# %% [markdown]
# **Evaluating the model on the test set**

# %%
test_model = keras.models.load_model(
    "feature_extraction_with_data_augmentation.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 63/63 [==============================] - 312s 5s/step - loss: 2.4681 - accuracy: 0.9765
# Test accuracy: 0.976

# %% [markdown]
# ### Fine-tuning a pretrained model

# %%
conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  block5_conv1 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_pool (MaxPooling2D)  (None, None, None, 512)   0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# **Freezing all layers until the fourth from the last**

# %%
conv_base.trainable = True
for layer in conv_base.layers[:-4]:
    layer.trainable = False

# %% [markdown]
# **Fine-tuning the model**

# %%
model.compile(loss="binary_crossentropy",
              optimizer=keras.optimizers.RMSprop(learning_rate=1e-5),
              metrics=["accuracy"])

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="fine_tuning.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/30
# 63/63 [==============================] - 626s 10s/step - loss: 3.4427 - accuracy: 0.7655 - val_loss: 0.5876 - val_accuracy: 0.9360
# Epoch 2/30
# 63/63 [==============================] - 522s 8s/step - loss: 1.0673 - accuracy: 0.8730 - val_loss: 0.3542 - val_accuracy: 0.9450
# Epoch 3/30
# 63/63 [==============================] - 505s 8s/step - loss: 0.6105 - accuracy: 0.9060 - val_loss: 0.2122 - val_accuracy: 0.9640
# Epoch 4/30
# 63/63 [==============================] - 502s 8s/step - loss: 0.3910 - accuracy: 0.9185 - val_loss: 0.1656 - val_accuracy: 0.9730
# Epoch 5/30
# 63/63 [==============================] - 527s 8s/step - loss: 0.2903 - accuracy: 0.9360 - val_loss: 0.1576 - val_accuracy: 0.9700
# Epoch 6/30
# 63/63 [==============================] - 732s 12s/step - loss: 0.2543 - accuracy: 0.9325 - val_loss: 0.1492 - val_accuracy: 0.9680
# Epoch 7/30
# 63/63 [==============================] - 636s 10s/step - loss: 0.1925 - accuracy: 0.9455 - val_loss: 0.1685 - val_accuracy: 0.9710
# Epoch 8/30
# 63/63 [==============================] - 683s 11s/step - loss: 0.1812 - accuracy: 0.9555 - val_loss: 0.1465 - val_accuracy: 0.9700
# Epoch 9/30
# 63/63 [==============================] - 16802s 271s/step - loss: 0.1404 - accuracy: 0.9585 - val_loss: 0.1253 - val_accuracy: 0.9740
# Epoch 10/30
# 63/63 [==============================] - 486s 8s/step - loss: 0.1189 - accuracy: 0.9620 - val_loss: 0.1343 - val_accuracy: 0.9760
# Epoch 11/30
# 63/63 [==============================] - 509s 8s/step - loss: 0.1053 - accuracy: 0.9710 - val_loss: 0.1302 - val_accuracy: 0.9750
# Epoch 12/30
# 63/63 [==============================] - 568s 9s/step - loss: 0.1054 - accuracy: 0.9635 - val_loss: 0.1205 - val_accuracy: 0.9750
# Epoch 13/30
